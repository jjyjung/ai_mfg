# %% [markdown]
# <a href="https://colab.research.google.com/github/jjyjung/ai_mfg/blob/main/%ED%9A%8C%EC%A0%84%EA%B8%B0%EA%B3%84_%EA%B3%A0%EC%9E%A5%EC%A7%84%EB%8B%A8_DL%EC%8B%A4%EC%8A%B5_torch_v6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **회전기계 고장진단 실습**
#
# **제목:** 회전기계의 고장유형 분석을 위한 AI 데이터셋 가이드북  <br>
# **Description:** 회전기계로부터 수집한 데이터를 전처리하고, 신경망 학습을 이용하여 회전기계의 정상/고장 여부 및 고장 유형을 판단하고자 함
#
# 본 자료는 정부에서 운영하는 아래의 KAMP(한국인공지능제조플랫폼)의 데이터 및 예제를 수정한 교육자료입니다.
#
# 중소벤처기업부, Korea AI Manufacturing Platform(KAMP), 회전기계 고장유형 AI 데이터셋, KAIST, 2021.12.27., https://kamp-ai.kr
#
# https://www.kamp-ai.kr/front/dataset/AiDataDetail.jsp?AI_SEARCH=&page=1&DATASET_SEQ=18

# %% [markdown]
# ※ 분석하기에 앞서 다음과 같은 가상환경이 구축되어있는지 확인해주세요. <br>
# Python 버전 : 3.7.3
#
# 위의 버전과 다른 경우 오류가 발생할 수 있습니다.

# %%
# !python --version
# Out:
# Python 3.10.12

# %% [markdown]
# # **Introduction**
#
# **제목:** 회전기계의 고장유형 분석을 위한 AI 데이터셋 가이드북  <br>
# **Description:** 회전기계로부터 수집한 데이터를 전처리하고, 신경망 학습을 이용하여 회전기계의 정상/고장 여부 및 고장 유형을 판단하고자 함

# %% [markdown]
# ## 0. 회전기계 (Rotor testbed)
#
# > 산업 현장에서 사용되는 기계 구조물은 대부분 정상 상태로 가동되며, 수집되는 데이터 역시 정상 유형이 90% 이상을 차지한다. 고장유형의 경우 자연 발생적으로 취득되는 데이터가 매우 희박하고, 실제 구조물에 인위적인 고장을 가하여 데이터를 취득하는 방식은 비효율적이므로, 이는 데이터간 불균형 문제를 초래할 수 있다. Rotor testbed를 이용하면, 여러 고장유형에 대해 특징을 분석하고, 정상 및 고장유형을 분류할 수 있는 충분한 양의 고장 데이터를 수집할 수 있다. 많은 산업 현장(발전소 등)에서 주로 사용되는 회전 설비의 진동데이터를 수집하고, 고장을 분석 및 진단하는 학습 모델을 구축하여, 이후 기술 확장을 통해 발전소나, 대규모 공장의 자동화 라인 등에 활용을 목표로 한다.
#
# ![fig.01.png](https://raw.githubusercontent.com/jjyjung/ai/gh-pages/img/fig.01.png)

# %% [markdown]
# (1) Controller Module
# - Rotor testbed의 controller는 수동 모드와 자동 모드 2개의 모드가 있다.
# - 수동 모드의 경우 0 ~ 3000 RPM 까지 Motor의 회전속도 조절이 가능하다.
# - 본 가이드 북에서는 수동 모드를 이용하여 Motor 회전속도가 약 1500 RPM인 경우, 진동 데이터를 구축하였다. <br>
# <br>
#
# (2) BLDC Motor
# - 본 가이드 북에서 사용된 rotor testbed의 BLDC Motor는 Brush가 제거된 형태로 브러쉬를 통한 기계적인 접촉이 없는 DC Motor이다.
# - BLDC Motor는 소음이 비교적 적으며, 출력을 세밀하게 조절할 수 있다는 장점이 있다.<br>
# <br>
#
# (3) Disks
# ![fig.02.png](https://raw.githubusercontent.com/jjyjung/ai/gh-pages/img/fig.02.png)
# - 본 가이드 북에서 사용된 rotor testbed는 총 2개의 aluminum disk가 있다.
# - 각각의 disk에는 회전 불균형을 구현할 수 있는 bolt 체결 홀이 있다.
# - 축의 중심으로부터 bolt 체결 홀의 거리는 약 60mm이며, Blot 체결 홀은 모두 36개이다.<br>
# <br>
#
# (4) Spec
# - 본 가이드 북에서 사용된 rotor testbed의 사양은 다음과 같다.
#
# |    구분    |                 사양                 |
# |:----------:|:------------------------------------:|
# | Size       | 673 mm (W) x 280 mm (D) x 281 mm (H) |
# | Weight     |                 25kg                 |
# | Material   |               Aluminum               |
# | Bearing    |             6202ZZ x 2EA             |
# | Motor      |  DC 12V x 0.25HP (0.2W), 0-3000 RPM  |
# | Main power |                220 VAC               |
#
# (5) Experiment environment
# - 본 가이드 북에서 사용된 rotor testbed의 실험 환경은 다음과 같다.
# - 회전 속도는 약 1500 RPM을 사용하였으며, 이 경우 기계의 최대 주파수는 25 Hz가 된다.
# - Nyquist 이론에 의해 기계의 최대 주파수의 2배 이상으로 sampling rate을 설정해야하며, 측정값의 신호를 분석하기 위해서는 5-10배 정도의 sampling rate이 요구된다. 본 가이드 북에서 사용된 RPM에 따른 적절한 sampling rate는 125-250 Hz 정도이며, 이번 실험에서는 Z방향 진동 데이터(가속도)를 1 kHz로 sampling하여 사용할 예정이다.
#
# | Rotor testbed |                   |
# |:-------------:|:-----------------:|
# | RPM           |     about 1500    |
# | Sampling rate | 1 kHz (0.001 sec) |

# %% [markdown]
# ## 1. 라이브러리 / 데이터 불러오기
#
# ### 1-1. 라이브러리 불러오기
#
# 필요한 라이브러리를 불러온다.  <br>
# 오류가 발생할 경우, !pip install 패키지명을 입력하여 설치하도록 한다.
#
# (EX) !pip install numpy
#
# 본 가이드북에서 필요한 패키지들은 모두 requirements.txt에 있다.

# %%
# 아래 requirements.txt의 버전에 맞는 module을 설치하지 않았다면 오류가 발생할 수 있습니다.
# !pip install -r requirements.txt

# %%
import numpy as np
import pandas as pd
import random
import seaborn as sns
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1-2. 데이터 불러오기
#
# pd.read_csv(“데이터파일_경로명”)을 통해 csv 형태의 데이터를 pandas의 DataFrame으로 읽어 들인다.  <br>
#
# - 총 4개의 센서를 사용하므로 sensor1~sensor4로 명명하였다.  <br>
# - 센서 데이터 취득 위치는 다음과 같다.<br>
# <br>
#
# ![sensor1.png](https://raw.githubusercontent.com/jjyjung/ai/gh-pages/img/sensor1.png)<br>
# <center>[센서 설치 위치 (사진)]</center> <br>
#
# ![sensor2.png](https://raw.githubusercontent.com/jjyjung/ai/gh-pages/img/sensor2.png)<br>
# <center>[group 1]</center> <br>
#
# ![sensor3.png](https://raw.githubusercontent.com/jjyjung/ai/gh-pages/img/sensor3.png)<br>
# <center>[group 2]</center> <br>
# <br>
#
# - data는 데이터 취득 시간, 정상 유형(normal)과 고장유형 1-3 (type1, type2, type3)일 경우 센서 취득값으로 구성된다.  <br>
# - 고장유형 1,2,3은 다음의 사진과 표를 확인하면 알 수 있다.<br>
#
# ![fault_type.png](https://raw.githubusercontent.com/jjyjung/ai/gh-pages/img/fault_type.png)<br>
#
# | 구분   | 특징                                                |
# |--------|-----------------------------------------------------|
# | Type 1 | Disk 2에 회전 불균형 (270도 위치에 볼트, 너트 부착) |
# | Type 2 | Support 4에 지지 불균형                             |
# | Type 3 | Type 1 + Type 2                                     |

# %%
from google.colab import drive
drive.mount('/content/gdrive')   # google drive를 google colab에 연결. 처음 실행 시, 인증 필요
# Out:
# Mounted at /content/gdrive

# %%
# 데이터를 읽어 들이고 정규화하기
dir = "/content/gdrive/My Drive/Colab Notebooks/ai_mfg/rotor/"  ### [중요!!] Colab의 경우, 파일을 저장한 위치를 기록하시오.

# %%
# group 1의 데이터를 사용할 경우, 아래 코드를 실행합니다.
sensor1 = pd.read_csv(dir+'g1_sensor1.csv', names = ['time', 'normal', 'type1', 'type2', 'type3'])
sensor2 = pd.read_csv(dir+'g1_sensor2.csv', names = ['time', 'normal', 'type1', 'type2', 'type3'])
sensor3 = pd.read_csv(dir+'g1_sensor3.csv', names = ['time', 'normal', 'type1', 'type2', 'type3'])
sensor4 = pd.read_csv(dir+'g1_sensor4.csv', names = ['time', 'normal', 'type1', 'type2', 'type3'])

# # group 2의 데이터를 사용할 경우, 주석을 제거하고 아래 코드를 실행합니다.
# sensor1 = pd.read_csv(dir+'g2_sensor1.csv', names = ['time', 'normal', 'type1', 'type2', 'type3'])
# sensor2 = pd.read_csv(dir+'g2_sensor2.csv', names = ['time', 'normal', 'type1', 'type2', 'type3'])
# sensor3 = pd.read_csv(dir+'g2_sensor3.csv', names = ['time', 'normal', 'type1', 'type2', 'type3'])
# sensor4 = pd.read_csv(dir+'g2_sensor4.csv', names = ['time', 'normal', 'type1', 'type2', 'type3'])

# %% [markdown]
# ### 1-3. 데이터 확인
# 불러온 데이터프레임의 변수 이름(normal_)을 입력하면 해당 내용을 확인해 볼 수 있다.

# %%
sensor1
# Out:
#               time    normal     type1     type2     type3
# 0         0.000000 -0.853307 -3.464579  0.555219  3.919664
# 1         0.000736 -0.740463 -2.448986 -0.234687  4.145351
# 2         0.001472 -0.138630 -1.922383 -0.009000  2.941685
# 3         0.002208  0.049443 -0.906790 -0.272301  2.603155
# 4         0.002944 -0.289088 -0.568259 -0.986978  1.361874
# ...            ...       ...       ...       ...       ...
# 190213  139.996768 -1.156354 -2.696750  0.844491 -2.109427
# 190214  139.997504 -0.930666 -1.380241  0.919720 -2.222270
# 190215  139.998240 -0.554521 -2.132532  0.731647 -2.109427
# 190216  139.998976 -1.419655 -2.433448  1.183022 -3.087405
# 190217  139.999712 -0.441677 -2.245376  1.333480 -2.184656
#
# [190218 rows x 5 columns]

# %% [markdown]
# 데이터는 140초 간의 시간을 포함하여 총 5개의 컬럼으로 이루어져 있다. <br>

# %%
print('sensor 1의 데이터 크기', sensor1.shape)
print('sensor 2의 데이터 크기', sensor2.shape)
print('sensor 3의 데이터 크기', sensor3.shape)
print('sensor 4의 데이터 크기', sensor4.shape)
# Out:
# sensor 1의 데이터 크기 (190218, 5)
# sensor 2의 데이터 크기 (184211, 5)
# sensor 3의 데이터 크기 (196079, 5)
# sensor 4의 데이터 크기 (183969, 5)

# %% [markdown]
# 그러나 데이터를 확인하면 센서마다 데이터를 취득하는 sampling rate이 다르기 때문에, 데이터의 사이즈가 다른 것을 확인할 수 있다. <br>
# 따라서 본 가이드북에서는 동일한 time interval의 데이터를 취득하기 위해 데이터를 0.001 sec 간격으로 선형보간하겠다.

# %% [markdown]
# ### 1-4. 데이터 보간
# #### 데이터 선형보간
#
# 각 센서별 sampling rate은 다음과 같다. <br>
#
# | Sensor 1 | Sensor 2 | Sensor 3 | Sensor 4 |
# |:--------:|:--------:|----------|----------|
# | 0.000736 | 0.000760 | 0.000714 | 0.000761 |
#
# 계측된 센서 데이터의 계측 시간 간격 (sampling rate)이 일정하지 않은 경우, 데이터 간 정확한 비교가 어려우므로 계측 시간의 동일화를 위해 전처리(선형 보간)가 요구된다. 선형보간의 방법은 아래 그림과 같다.
# <br>
# ![interpolation.png](https://raw.githubusercontent.com/jjyjung/ai/gh-pages/img/interpolation.png)<br>
# <br>
# 따라서 표에 나온 sampling rate을 이용하여 각 센서의 데이터를 0.001 sec 간격으로 선형보간 한다 (총 140초). <br>
#  - interpolate.interp1d() : [선형보간 함수](https://docs.scipy.org/doc/scipy/reference/generated/scipy.interpolate.interp1d.html)를 이용하였다.

# %%
from scipy import interpolate

x_new = np.arange(0, 140, 0.001)

y_new1 = []; y_new2 = []; y_new3 = []; y_new4 = []
for item in ['normal', 'type1', 'type2', 'type3']:
    f_linear1 = interpolate.interp1d(sensor1['time'], sensor1[item], kind='linear'); y_new1.append(f_linear1(x_new))
    f_linear2 = interpolate.interp1d(sensor2['time'], sensor2[item], kind='linear'); y_new2.append(f_linear2(x_new))
    f_linear3 = interpolate.interp1d(sensor3['time'], sensor3[item], kind='linear'); y_new3.append(f_linear3(x_new))
    f_linear4 = interpolate.interp1d(sensor4['time'], sensor4[item], kind='linear'); y_new4.append(f_linear4(x_new))

sensor1 = pd.DataFrame(np.array(y_new1).T, columns = ['normal', 'type1', 'type2', 'type3'])
sensor2 = pd.DataFrame(np.array(y_new2).T, columns = ['normal', 'type1', 'type2', 'type3'])
sensor3 = pd.DataFrame(np.array(y_new3).T, columns = ['normal', 'type1', 'type2', 'type3'])
sensor4 = pd.DataFrame(np.array(y_new4).T, columns = ['normal', 'type1', 'type2', 'type3'])

# %%
sensor1
# Out:
#           normal     type1     type2     type3
# 0      -0.853307 -3.464579  0.555219  3.919664
# 1      -0.524588 -2.260096 -0.153734  3.713601
# 2      -0.003708 -1.193805 -0.197890  2.698827
# 3      -0.297674 -0.490986 -0.972668  1.338978
# 4      -0.091203  0.790771 -0.913384  0.701167
# ...          ...       ...       ...       ...
# 139995 -1.057411 -1.389236  0.664186 -1.498190
# 139996 -0.513635 -1.368793  1.050553 -0.982626
# 139997 -1.085213 -2.281763  0.868204 -2.144997
# 139998 -0.677177 -1.887220  0.792975 -2.146224
# 139999 -1.387764 -2.427315  1.187928 -3.057968
#
# [140000 rows x 4 columns]

# %% [markdown]
# 선형 보간 작업을 위해 데이터를 센서별로 묶어두었지만, 실제 취득된 형태로 데이터를 다시 조정한다.

# %%
normal_ = pd.concat([sensor1['normal'],sensor2['normal'],sensor3['normal'],sensor4['normal']],axis=1)
type1_  = pd.concat([sensor1['type1'], sensor2['type1'], sensor3['type1'], sensor4['type1']], axis=1)
type2_  = pd.concat([sensor1['type2'], sensor2['type2'], sensor3['type2'], sensor4['type2']], axis=1)
type3_  = pd.concat([sensor1['type3'], sensor2['type3'], sensor3['type3'], sensor4['type3']], axis=1)

normal_.columns = ['s1', 's2', 's3', 's4']; type1_.columns = ['s1', 's2', 's3', 's4']
type2_.columns  = ['s1', 's2', 's3', 's4']; type3_.columns = ['s1', 's2', 's3', 's4']

# %%
normal_
# Out:
#               s1        s2        s3        s4
# 0      -0.853307  0.048823 -0.437626 -1.116226
# 1      -0.524588 -0.029477 -0.149817 -0.659694
# 2      -0.003708 -0.004751  0.280889 -0.857345
# 3      -0.297674  0.009673 -0.303281 -0.685318
# 4      -0.091203  0.096215 -0.320263 -0.303108
# ...          ...       ...       ...       ...
# 139995 -1.057411  0.587429  0.275044  0.289837
# 139996 -0.513635 -0.137874 -0.045973  0.131462
# 139997 -1.085213  0.002242 -0.164593 -0.087380
# 139998 -0.677177 -0.308897  0.288252  1.319862
# 139999 -1.387764 -0.731303  0.395425 -0.125739
#
# [140000 rows x 4 columns]

# %%
print('normal 상태 데이터의 사이즈', normal_.shape)
print('type1  상태 데이터의 사이즈', type1_.shape)
print('type2  상태 데이터의 사이즈', type2_.shape)
print('type3  상태 데이터의 사이즈', type3_.shape)
# Out:
# normal 상태 데이터의 사이즈 (140000, 4)
# type1  상태 데이터의 사이즈 (140000, 4)
# type2  상태 데이터의 사이즈 (140000, 4)
# type3  상태 데이터의 사이즈 (140000, 4)

# %% [markdown]
# ### 1-5. 데이터 분석
# #### 데이터 시각화
# 특정 시간에서의 시계열 샘플을 플롯

# %%
# python 버전 : 3.7.3 (버전에 따라, jupyter notebook에서 아래 코드가 실행되지 않을 수 있습니다)
# 실행이 되지 않는 경우, 아래 코드는 주석처리하고 넘어가도 학습에 영향을 주지 않습니다 (데이터 확인용)

plt.figure(figsize = (10, 4))
plt.scatter(range(0,300), normal_['s1'][:300], label="class = " + str(1), marker='o', s=5)
plt.scatter(range(0,300), type1_['s1'][:300], label="class = " + str(2), marker='o', s=5)

plt.legend(loc="lower right")
plt.xlabel("Sensor", fontsize=15)
plt.ylabel("Sensor Value", fontsize=15)
plt.show()
plt.close()

# %% [markdown]
# #### 데이터 상관분석
# df.corr()을 입력하면 센서 별 상관관계를 확인할 수 있다.

# %%
normal_.corr()
# Out:
#           s1        s2        s3        s4
# s1  1.000000 -0.007093  0.004297 -0.003377
# s2 -0.007093  1.000000 -0.002992  0.111121
# s3  0.004297 -0.002992  1.000000 -0.006434
# s4 -0.003377  0.111121 -0.006434  1.000000

# %% [markdown]
# Correlation Matrix(상관 행렬)를 통해 센서값 별 상관관계를 이미지로 확인할 수 있다.

# %%
# python 버전 : 3.7.3 (버전에 따라, jupyter notebook에서 아래 코드가 실행되지 않을 수 있습니다)
# 실행이 되지 않는 경우, 아래 코드는 주석처리하고 넘어가도 학습에 영향을 주지 않습니다 (데이터 확인용)

names = ['s1','s2','s3','s4']
cm = np.corrcoef(normal_[names].values.T)
sns.set(font_scale=0.8)
sns.heatmap(cm, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=names, xticklabels=names, cmap=plt.cm.Blues)
# Out:
# <Axes: >

# %% [markdown]
# 절대값이 0.6보다 클수록 강한 상관관계를 가지며, 0.3보다 작을수록 약한 상관관계를 갖는다. <br>
# 양수의 경우 정(+)의 상관관계, 음수의 경우 부(-)의 상관관계를 갖는다.

# %% [markdown]
# ## 2. 데이터 전처리
#
# ### 2-1. 데이터 필터링 (Filtering)
#
# 센서로부터 취득한 데이터는 기본적으로 기계학습에 좋지 않은 영향을 주는 노이즈(Noise)가 포함되어 있다. 센서 데이터에 평균을 취하면 데이터의 노이즈를 제거할 수 있는데, 측정하려는 물리량이 시간에따라 변하는 경우에는 적절하지 않다(데이터의 동적인 변화를 모두 smoothing하는 결과). 따라서 데이터에서 노이즈를 제거하면서, 동적인 변화를 반영하는 방법으로 이동평균필터가 있으며, 본 가이드북에서는 데이터의 노이즈를 처리하기 위해 이동평균필터(Moving Average filter)를 사용하였다.
#
# - 이동평균필터 (Moving Average filter)는 python에서 [np.convolve()](https://numpy.org/doc/stable/reference/generated/numpy.convolve.html) 함수로 구현된다 (MATLAB의 filter 함수와 동일). <br>
#     - np.convolve() : 1차원 신호를 입력으로 받아, 최근 M개의 측정값들의 평균을 구한다.
#
#     - 모든 데이터의 평균이 아니라, 정해진 크기(M개)의 최근 측정값들로만 평균을 구한다. <br>
#     - 일반적으로 신호 데이터의 변동이 빠른 경우에는 M값을 작게하고, 신호 데이터의 변동이 느린 경우에는 M값을 크게한다. <br>
#     - 자세한 이론은 [자료](https://www.analog.com/media/en/technical-documentation/dsp-book/dsp_book_Ch15.pdf)를 참고하면 좋다.

# %%
M = 15

normal_s1 = np.convolve(normal_['s1'], np.ones(M), 'valid') / M; normal_s1 = normal_s1.reshape(len(normal_s1),1)
normal_s2 = np.convolve(normal_['s2'], np.ones(M), 'valid') / M; normal_s2 = normal_s2.reshape(len(normal_s2),1)
normal_s3 = np.convolve(normal_['s3'], np.ones(M), 'valid') / M; normal_s3 = normal_s3.reshape(len(normal_s3),1)
normal_s4 = np.convolve(normal_['s4'], np.ones(M), 'valid') / M; normal_s4 = normal_s4.reshape(len(normal_s4),1)

type1_s1 = np.convolve(type1_['s1'], np.ones(M), 'valid') / M; type1_s1 = type1_s1.reshape(len(type1_s1),1)
type1_s2 = np.convolve(type1_['s2'], np.ones(M), 'valid') / M; type1_s2 = type1_s2.reshape(len(type1_s2),1)
type1_s3 = np.convolve(type1_['s3'], np.ones(M), 'valid') / M; type1_s3 = type1_s3.reshape(len(type1_s3),1)
type1_s4 = np.convolve(type1_['s4'], np.ones(M), 'valid') / M; type1_s4 = type1_s4.reshape(len(type1_s4),1)

type2_s1 = np.convolve(type2_['s1'], np.ones(M), 'valid') / M; type2_s1 = type2_s1.reshape(len(type2_s1),1)
type2_s2 = np.convolve(type2_['s2'], np.ones(M), 'valid') / M; type2_s2 = type2_s2.reshape(len(type2_s2),1)
type2_s3 = np.convolve(type2_['s3'], np.ones(M), 'valid') / M; type2_s3 = type2_s3.reshape(len(type2_s3),1)
type2_s4 = np.convolve(type2_['s4'], np.ones(M), 'valid') / M; type2_s4 = type2_s4.reshape(len(type2_s4),1)

type3_s1 = np.convolve(type3_['s1'], np.ones(M), 'valid') / M; type3_s1 = type3_s1.reshape(len(type3_s1),1)
type3_s2 = np.convolve(type3_['s2'], np.ones(M), 'valid') / M; type3_s2 = type3_s2.reshape(len(type3_s2),1)
type3_s3 = np.convolve(type3_['s3'], np.ones(M), 'valid') / M; type3_s3 = type3_s3.reshape(len(type3_s3),1)
type3_s4 = np.convolve(type3_['s4'], np.ones(M), 'valid') / M; type3_s4 = type3_s4.reshape(len(type3_s4),1)

# %%
normal_temp = np.concatenate((normal_s1,normal_s2,normal_s3,normal_s4), axis = 1)
type1_temp = np.concatenate((type1_s1,type1_s2,type1_s3,type1_s4), axis = 1)
type2_temp = np.concatenate((type2_s1,type2_s2,type2_s3,type2_s4), axis = 1)
type3_temp = np.concatenate((type3_s1,type3_s2,type3_s3,type3_s4), axis = 1)

# %% [markdown]
# ### 2-2. 데이터 정규화
#
# 데이터 (140000,4)의 센서 값들이 다양한 Range를 갖는다. <br>
# 이는 신경망 학습에 그대로 이용하기엔 적절하지 않다. <br>
# 일반적으로 인풋 값들을 정규화(Normalization)하는데, 본 가이드북에서는 Min-max normalization 활용하여 진행하였다. <br>
# Min-max normalization는 데이터를 0과 1 사이의 값으로 scaling한다.
#
# 1) Normal data의 최대값(max)과 최소값(min)을 구한다. <br>
# 2) 정규화할 데이터 값(x)과 앞서 구한 최대값(Xmax), 최소값(Xmin)을 다음의 식에 대입한다.
#
# ![sensor1.png](https://raw.githubusercontent.com/jjyjung/ai/gh-pages/img/minmax.png)<br>
# 3) 이와 같은 식은 sklearn.preprocessing의 MinMaxScaler에 구현되어있다.

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(normal_)
normal = scaler.transform(normal_temp)
type1  = scaler.transform(type1_temp)
type2  = scaler.transform(type2_temp)
type3  = scaler.transform(type3_temp)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# 1) MinMaxScaler.fit을 통해 normal data의 min, max를 구한다. <br>
# 2) MinMaxScaler.transform를 통해 각 데이터를 normal data의 min, max 값으로 정규화한다.
#
# 데이터 확인

# %%
print(normal)
print('------------------------------------------------')
print('normal data size = ', normal.shape)
# Out:
# [[0.57598822 0.50553898 0.56439491 0.44551164]
#  [0.60960317 0.50513674 0.58169332 0.44848001]
#  [0.62990663 0.5047345  0.59547186 0.46260474]
#  ...
#  [0.51874981 0.50106998 0.60999194 0.50715712]
#  [0.49713039 0.51588928 0.6074125  0.53093987]
#  [0.45708747 0.52025039 0.60349765 0.53976513]]
# ------------------------------------------------
# normal data size =  (139986, 4)

# %% [markdown]
# 이동평균 필터링 후에 데이터의 사이즈를 조정한다(옵션, 본 가이드 북에서는 숫자를 쉽게 확인할 수 있도록 함). <br>
# rotor testbed 가동 후 몇 초간 (약 30초)의 데이터를 탈락시키고 이후 데이터를 사용하였다(steady state). <br>
#
# 데이터 사이즈를 (100000, 4)로 맞춰주었다.

# %%
normal = normal[30000:130000][:]
type1  = type1[30000:130000][:]
type2  = type2[30000:130000][:]
type3  = type3[30000:130000][:]

# %%
print(normal)
print('------------------------------------------------')
print('normal data size = ', normal.shape)
# Out:
# [[0.42588581 0.56360116 0.59076635 0.45259554]
#  [0.39980512 0.54859132 0.57699856 0.4486034 ]
#  [0.38031149 0.54190146 0.57998374 0.44726771]
#  ...
#  [0.48028648 0.53048363 0.62114742 0.51024851]
#  [0.44818273 0.53444251 0.62103995 0.49126006]
#  [0.42832757 0.5501298  0.60917718 0.47827626]]
# ------------------------------------------------
# normal data size =  (100000, 4)

# %% [markdown]
# ### 2-3. 데이터 분배
#
# Normal, type1-3 abnormal data를 1:1:1:1의 비율로 각각 training data, validation data, test data로 나눈다. <br>
# 이 때, 학습 : 검증 : 테스트 = 6 : 2 : 2 이다.

# %%
# 데이터 분배
normal_train = normal[:][:60000]; normal_valid = normal[:][60000:80000]; normal_test = normal[:][80000:]
type1_train  = type1[:][:60000];  type1_valid  = type1[:][60000:80000];  type1_test  = type1[:][80000:]
type2_train  = type2[:][:60000];  type2_valid  = type2[:][60000:80000];  type2_test  = type2[:][80000:]
type3_train  = type3[:][:60000];  type3_valid  = type3[:][60000:80000];  type3_test  = type3[:][80000:]

train = np.concatenate((normal_train,type1_train,type2_train,type3_train))
valid = np.concatenate((normal_valid,type1_valid,type2_valid,type3_valid))
test = np.concatenate((normal_test,type1_test,type2_test,type3_test))

# %%
print("train data의 형태:", train.shape)
print("valid data의 형태:", valid.shape)
print(" test data의 형태:", test.shape)
# Out:
# train data의 형태: (240000, 4)
# valid data의 형태: (80000, 4)
#  test data의 형태: (80000, 4)

# %% [markdown]
# #### 데이터 라벨 부여 및 뒤섞기
# Normal data = 0 <br>
# Type1  data = 1 <br>
# Type2  data = 2 <br>
# Type3  data = 3 <br>
# 학습을 위해 각 데이터에 라벨을 부여하고, 학습을 위해 뒤섞는다. <br>
# - train data는 train epoch마다 랜덤한 순서로 학습하기 위해 dataloader를 이용하여 shuffle<br>
# - valid data와 test data는 실행할 때 고정된 임의의 순서로 가져오기 위해 shuffle 함수 사용<br>

# %%
train_label = np.concatenate((np.full((60000,1),0),np.full((60000,1),1),np.full((60000,1),2),np.full((60000,1),3)))
valid_label = np.concatenate((np.full((20000,1),0),np.full((20000,1),1),np.full((20000,1),2),np.full((20000,1),3)))
test_label = np.concatenate((np.full((20000,1),0),np.full((20000,1),1),np.full((20000,1),2),np.full((20000,1),3)))

# %%
idx = np.arange(train.shape[0]); np.random.shuffle(idx); train = train[:][idx];
train_label = train_label[:][idx]

idx_v = np.arange(valid.shape[0]); np.random.shuffle(idx_v); valid = valid[:][idx_v];
valid_label = valid_label[:][idx_v]

idx_t = np.arange(test.shape[0]); np.random.shuffle(idx_t); test = test[:][idx_t];
test_label = test_label[:][idx_t]

# %% [markdown]
# 신경망 구조에 입력하기 전 data를 tensor 형태로 변경

# %%
x_train = torch.from_numpy(train).float()
y_train = torch.from_numpy(train_label).float().T[0]

x_valid = torch.from_numpy(valid).float()
y_valid = torch.from_numpy(valid_label).float().T[0]

x_test = torch.from_numpy(test).float()
y_test = torch.from_numpy(test_label).float().T[0]

# %%
print("변경 전")
train
# Out:
# 변경 전
# array([[0.60805166, 0.5043624 , 0.61226569, 0.64924475],
#        [0.21009772, 0.37736689, 0.58582272, 0.30726668],
#        [0.16031963, 0.39117392, 0.61873836, 0.64119813],
#        ...,
#        [0.97067949, 0.56682799, 0.63927186, 0.4909262 ],
#        [0.05098805, 0.29136855, 0.55687867, 0.63204991],
#        [0.89877908, 0.28812967, 0.6395339 , 0.58906323]])

# %%
print("변경 후")
x_train
# Out:
# 변경 후
# tensor([[0.6081, 0.5044, 0.6123, 0.6492],
#         [0.2101, 0.3774, 0.5858, 0.3073],
#         [0.1603, 0.3912, 0.6187, 0.6412],
#         ...,
#         [0.9707, 0.5668, 0.6393, 0.4909],
#         [0.0510, 0.2914, 0.5569, 0.6320],
#         [0.8988, 0.2881, 0.6395, 0.5891]])

# %%
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader

train = TensorDataset(x_train, y_train)
train_dataloader = DataLoader(train, batch_size = 5000, shuffle=True)

valid = TensorDataset(x_valid, y_valid)
valid_dataloader = DataLoader(valid, batch_size = len(x_valid), shuffle=False)

test = TensorDataset(x_test, y_test)
test_dataloader = DataLoader(test, batch_size = len(x_valid), shuffle=False)

# %% [markdown]
# ## 3. 모델 구축
#
# ### 3-1. 심층신경망 (DNN)
#
# 심층신경망(DNN)은 인공신경망에서 모델 내 은닉층을 많이 늘려서 학습의 결과를 향상시키는 방법이다. <br>
# 라벨이 있는 데이터이므로, supervised learning을 통해 classification을 위한 학습 모델을 구축한다.
#
# pytorch의 network는 class 형태로 구성된다.
# 자세한 내용은 pytorch 공식 사이트에서 확인 가능하다(링크 포함).
#
# 1. ```KAMP_DNN을 구현하는 class는 nn.Module class를 상속한다.```
# 2. ```__init__에서는 신경망 layer를 초기화한다.```
#    -   nn.Linear() : [선형계층](https://pytorch.org/docs/stable/generated/torch.nn.Linear.html)으로 weight와 bias을 사용하여 입력에 선형 변환을 적용하는 모듈
#        - in_features  : 신경망으로 입력되는 size
#        - out_features : 신경망에서 출력되는 size <br>
#        <br>
#    -   nn.Relu() : [ReLU 활성화함수 계층](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html)으로 비선형 활성화를 통해 모델의 입력과 출력 사이에 복잡한 관계(mapping)를 만든다. <br>
#        비선형 활성화는 nn.Linear로 이루어진 선형계층에 비선형성을 도입하여 신경망이 보다 복잡한 현상을 학습할 수 있도록 돕는다.<br>
#        <br>
#    -   nn.Dropout() : [드롭아웃 계층](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html)으로 신경망의 일부를 의도적으로 학습에서 제외함으로써 모델을 일반화하는 역할을 한다(과적합 방지). <br>
#        ![fig.03.png](https://raw.githubusercontent.com/jjyjung/ai/gh-pages/img/fig.03.png)<br>
#         <br>
#    -   input_size = 4 : 계측되는 sensor 값들 4개
#    -   ouput_size = 4 : 정상 + 고장유형 개수 4개
#    -   hidden_size는 본 가이드 북에서는 100으로 하였으나, parameter study를 통해 조절
#    -   layer의 개수는 데이터에 따라 조절 (여기서는 2~4개의 layer 사용) <br>
#    <br>
# 3. ```forward 에서는 초기화된 레이어에 입력 데이터를 전달하고 최종 출력을 얻는다.```

# %%
# layer를 더 늘리고 싶은 경우 주석을 제거하고 사용합니다.

class KAMP_DNN(nn.Module):
    def __init__(self):
        super(KAMP_DNN, self).__init__()
        self.layer1   = nn.Linear(in_features = 4, out_features = 100)
        self.layer2   = nn.Linear(in_features = 100, out_features = 100)
        self.layer3   = nn.Linear(in_features = 100, out_features = 100)
        self.layer4   = nn.Linear(in_features = 100, out_features = 4)

        self.dropout  = nn.Dropout(0.2)
        self.relu     = nn.ReLU()

    def forward(self, input):
        out = self.layer1(input)
        out = self.relu(out)
        out = self.dropout(out)

        out = self.layer2(out)
        out = self.relu(out)
        out = self.dropout(out)

        out = self.layer3(out)
        out = self.relu(out)
        out = self.dropout(out)

        out = self.layer4(out)
        return out

model_check = KAMP_DNN()
print(model_check)
# Out:
# KAMP_DNN(
#   (layer1): Linear(in_features=4, out_features=100, bias=True)
#   (layer2): Linear(in_features=100, out_features=100, bias=True)
#   (layer3): Linear(in_features=100, out_features=100, bias=True)
#   (layer4): Linear(in_features=100, out_features=4, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (relu): ReLU()
# )

# %% [markdown]
# ### 3-2. 합성곱신경망 (CNN)
# 합성곱신경망(CNN)은 인공신경망의 한 종류이며, 주로 Matrix 데이터나 이미지 데이터에 대하여 특징을 추출하는데에 쓰인다. <br>
# 라벨이 있는 데이터이므로, supervised learning을 통해 classification을 위한 학습 모델을 구축한다. <br>
#
# pytorch의 network는 class 형태로 구성된다. 자세한 내용은 pytorch 공식 사이트에서 확인 가능하다(링크 포함).
#
# 1. ```KAMP_CNN을 구현하는 class는 nn.Module class를 상속한다.```
# 2. ```__init__에서는 신경망 layer를 초기화한다.```
#    -   nn.Sequential() : 계층이 순차적으로 실행되도록 담는 [sequential container](https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html)로서 연산순서를 원하는데로 다음 계층으로 전달할 수 있다. <br>
#    <br>
#    -   nn.Conv1d() : [1차원 합성곱 계층](https://pytorch.org/docs/stable/generated/torch.nn.Conv1d.html)으로서 주로 센서와 같은 시계열 데이터에 많이 사용된다.
#        - 이미지처리에서 주로 사용되는 2차원 합성곱 계층은 filter가 가로와 세로로 이동하면서 연산된다.
#        - 반면 1차원 합성곱 계층의 연산은 filter가 가로로만 이동하면서 output을 계산한다. <br>
#        ![fig.04.png](https://raw.githubusercontent.com/jjyjung/ai/gh-pages/img/fig.04.png)<br>
#        <br>
#        - input shape : torch.nn.conv1d의 입력 사이즈는 [Batch size, Input channel size, sequence length]이다. <br>
#            데이터를 학습하는 방식에 따라 입력 사이즈를 조절할 수 있으며, 본 가이드 북의 입력 사이즈는 다음과 같다. <br>
#            [Batch size = 80000, Input channel size = 1, sequence length = 4]
#             ![fig.05.png](https://raw.githubusercontent.com/jjyjung/ai/gh-pages/img/fig.05.png)<br>
#        <br>
#        - in_channels : 신경망으로 입력되는 데이터의 channel size (컬러 이미지의 경우 첫 계층에서 RGB = 3을 사용)<br>
#        - out_channels : 신경망에서 출력되는 데이터의 channel size (본 가이드북에서는 100을 사용하였으나 parameter study로 조절)<br>
#        - kernel_size : 특징을 추출하는 filter의 size<br>
#        - stride : kernel(filter)이 적용될 때, 이동하는 step size (2 이상인 경우, 데이터 size가 줄어든다)<br>
#        - padding : 데이터 가장자리에 0을 채워 넣는 역할 (default는 valid)<br>
#            {'vaild' : padding 안함, 'same' : 입력과 출력 size가 동일하도록 zero-padding, 혹은 다른 값}<br>
#        - bias : bias term의 사용 여부 (default는 True)<br>
#        <br>
#    -   nn.BatchNorm1d() : [Batch 차원에서의 정규화 계층](https://pytorch.org/docs/stable/generated/torch.nn.BatchNorm1d.html)으로 학습의 안정화에 기여한다.<br>
#        <br>
#    -   nn.Relu() : [ReLU 활성화함수 계층](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html)으로 비선형 활성화를 통해 모델의 입력과 출력 사이에 복잡한 관계(mapping)를 만든다. <br>
#        비선형 활성화는 nn.Linear로 이루어진 선형계층에 비선형성을 도입하여 신경망이 보다 복잡한 현상을 학습할 수 있도록 돕는다.<br>
#        <br>
#    -   nn.MaxPool1d() : [subsampling 계층](https://pytorch.org/docs/stable/generated/torch.nn.MaxPool1d.html)으로 데이터의 특징을 보존하면서 크기를 줄여주는 역할을 한다 (과적합 방지에 사용).<br>
#        평균적인 정보를 담는 average pooling과 가장 큰 정보를 담는 max pooling이 있다.
#        nn.Conv1d() 계층의 stride와 비슷한 역할을 하지만, 모든 정보를 가진 상태로 정보를 희석한다는 특징을 갖는다.
#    <br>
#    -   nn.Dropout() : [드롭아웃 계층](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html)으로 신경망의 일부를 의도적으로 학습에서 제외함으로써 모델을 일반화하는 역할을 한다(과적합 방지).<br>
#    <br>
#    -   layer의 개수는 데이터에 따라 조절 (여기서는 2~4개의 layer 사용) <br>
#    <br>
# 3. ```forward 에서는 초기화된 레이어에 입력 데이터를 전달하고 최종 출력을 얻는다.```

# %%
# layer를 더 늘리고 싶은 경우 주석을 제거하고 사용합니다.

class KAMP_CNN(nn.Module):
    def __init__(self):
        super(KAMP_CNN, self).__init__()
        self.conv1 = nn.Sequential(
        nn.Conv1d(in_channels=1, out_channels=100, kernel_size=2, stride=1, padding='same'),
        nn.BatchNorm1d(100),
        nn.ReLU(),
        nn.MaxPool1d(kernel_size=1, stride=1),
        nn.Dropout(p=0.2))

#         self.conv2 = nn.Sequential(
#         nn.Conv1d(in_channels=100, out_channels=100, kernel_size=2, stride=1, padding='same'),
#         nn.BatchNorm1d(100),
#         nn.ReLU(),
#         nn.MaxPool1d(kernel_size=1, stride=1),
#         nn.Dropout(p=0.2))

#         self.conv3 = nn.Sequential(
#         nn.Conv1d(in_channels=100, out_channels=100, kernel_size=2, stride=1, padding='same'),
#         nn.BatchNorm1d(100),
#         nn.ReLU(),
#         nn.MaxPool1d(kernel_size=1, stride=1),
#         nn.Dropout(p=0.2))

        self.conv4 = nn.Sequential(
        nn.Conv1d(in_channels=100, out_channels=4, kernel_size=2, stride=1, padding='same'),
        nn.BatchNorm1d(4),
        nn.ReLU(),
        nn.MaxPool1d(kernel_size=1, stride=1))

        self.final_pool = nn.AdaptiveAvgPool1d(1)
        self.linear = nn.Linear(4, 4)

    def forward(self, input):
        # 초기 input shape은 [80000, 4]이므로 input의 2번째 열(python에서는 1로 나타냄)에 채널 축을 확장 시킨다.
        input = input.unsqueeze(1)
        out = self.conv1(input)
#         out = self.conv2(out)
#         out = self.conv3(out)
        out = self.conv4(out)
        out = self.final_pool(out)
        out = self.linear(out.squeeze(-1))
        return out

model_check = KAMP_CNN()
print(model_check)
# Out:
# KAMP_CNN(
#   (conv1): Sequential(
#     (0): Conv1d(1, 100, kernel_size=(2,), stride=(1,), padding=same)
#     (1): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#     (4): Dropout(p=0.2, inplace=False)
#   )
#   (conv4): Sequential(
#     (0): Conv1d(100, 4, kernel_size=(2,), stride=(1,), padding=same)
#     (1): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (final_pool): AdaptiveAvgPool1d(output_size=1)
#   (linear): Linear(in_features=4, out_features=4, bias=True)
# )

# %% [markdown]
# 아래의 그림은 본 가이드 북에서 사용한 kernel과 stride size가 어떻게 작용하는지 시각적으로 확인하기 위한 예시를 나타내었다.
# ![fig.06.png](https://raw.githubusercontent.com/jjyjung/ai/gh-pages/img/fig.06.png)
#
# 다음의 코드로 확인 가능하다 (out_channels = 4).

# %%
print('--------------------------------------------------------------------')
input = torch.tensor([[[0.0, 6.0, 9.0, 1.0]]])
print('"input is same below."')
print(input)
print('--------------------------------------------------------------------')
model = nn.Conv1d(1, 4, 2, bias = False)
model.weight.data = torch.zeros(model.weight.data.size())
model.weight.data[:, :, :2] = 1
print('"kernal is same below."')
print(model.weight.data)
print('--------------------------------------------------------------------')
output = model(input)
print('"output is same below (without bias)."')
print(output)
print('--------------------------------------------------------------------')
model1 = nn.Conv1d(1, 4, 2)
model1.weight.data = torch.zeros(model1.weight.data.size())
model1.weight.data[:, :, :2] = 1
output = model1(input)
print('"output is same below (with bias)."')
print(output)
print('--------------------------------------------------------------------')
# Out:
# --------------------------------------------------------------------
# "input is same below."
# tensor([[[0., 6., 9., 1.]]])
# --------------------------------------------------------------------
# "kernal is same below."
# tensor([[[1., 1.]],
#
#         [[1., 1.]],
#
#         [[1., 1.]],
#
#         [[1., 1.]]])
# --------------------------------------------------------------------
# "output is same below (without bias)."
# tensor([[[ 6., 15., 10.],
#          [ 6., 15., 10.],
#          [ 6., 15., 10.],
#          [ 6., 15., 10.]]], grad_fn=<ConvolutionBackward0>)
# --------------------------------------------------------------------
# "output is same below (with bias)."
# tensor([[[ 5.3423, 14.3423,  9.3423],
#          [ 6.1713, 15.1713, 10.1713],
#          [ 5.6641, 14.6641,  9.6641],
#          [ 5.4803, 14.4803,  9.4803]]], grad_fn=<ConvolutionBackward0>)
# --------------------------------------------------------------------

# %% [markdown]
# ### 3-3. 순환신경망 (RNN)
# 순환신경망 (RNN, LSTM, GRU)은 과거의 학습을 가중치를 통해 현재 학습에 반영하는 특징이 있다. <br>
# 따라서 순차적으로 변화하는 시계열(time series) 데이터의 학습에 탁월한 효과를 갖는다.
# 본 가이드북에서는 pytorch의 LSTM 모듈을 사용하였다.
#
# 1. ```KAMP_CNN을 구현하는 class는 nn.Module class를 상속한다.```
# 2. ```__init__에서는 신경망 layer를 초기화한다.``` <br>
#
# | 구분 | 특징                                 |
# |------|--------------------------------------|
# | RNN  | 가장 기본적인 모델                   |
# | LSTM | RNN에서 gradient vanishing 문제 해소 |
# | GRU  | LSTM보다 빠른 속도                   |
#
#    -   nn.LSTM() : [LSTM 순환신경망 계층](https://pytorch.org/docs/stable/generated/torch.nn.LSTM.html) (Long Short-Term Memory Network)으로서 주로 시계열 데이터 처리에 많이 사용된다. <br>
#       - input shape : torch.nn.LSTM의 입력 사이즈는 [Batch size, sequence length, input size] 이다.
#        <br>
#        데이터를 학습시키는 방식에 따라 입력 사이즈를 조절할 수 있으며, 본 가이드 북의 입력 사이즈는 다음과 같다.<br>
#        [Batch size = 80000, sequence length = 1, input size = 4]<br>
#        <br>
#        - input size : 신경망으로 입력되는 데이터의 특징 개수 (time step 아님)
#        - hidden size : 은닉층에서 사용할 특징 개수 (적절한 값 사용)
#        - batch_first : [batch, sequence, feature]로 input data 사용 (default는 False, [sequence, batch, feature])
#        - num_layers : LSTM layer 개수 조절 옵션 (여기서는 4개의 layer 사용)
#        - dropout :  드롭아웃 옵션 (과적합 방지, default는 0)<br>
#    <br>
#    -   nn.Linear() : 선형계층으로 weight와 bias을 사용하여 입력에 선형 변환을 적용하는 모듈 <br>
#        여기서는 LSTM의 fully connected layer로 사용하였다.<br>
#        - in_features  : 신경망으로 입력되는 size
#        - out_features : 신경망에서 출력되는 size <br>
#         <br>
#
# 3. ```forward 에서는 초기화된 레이어에 입력 데이터를 전달하고 최종 출력을 얻는다.```

# %%
import torch
import torch.nn as nn

class KAMP_RNN(nn.Module):
    def __init__(self):
        super(KAMP_RNN, self).__init__()
        self.lstm    = nn.LSTM(input_size = 4, hidden_size = 100, num_layers = 2, batch_first=True, dropout = 0.2)
        self.fc      = nn.Linear(in_features = 100, out_features = 4)

    def forward(self, input):
        # 초기 input shape은 [80000, 4]이므로 input의 2번째 열(python에서는 1로 나타냄)에 채널 축을 확장 시킨다.
        input = input.unsqueeze(1)
        out, _ = self.lstm(input)
        # FC 계층에 입력하기 위해 채널 축을 축소한다.
        out = out.view(-1,100)
        output = self.fc(out)
        return output

model_check = KAMP_RNN()
print(model_check)
# Out:
# KAMP_RNN(
#   (lstm): LSTM(4, 100, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=100, out_features=4, bias=True)
# )

# %% [markdown]
# ## 4. 모델 학습

# %%
def train_model(model, criterion, optimizer, num_epoch, train_dataloader, PATH):
    loss_values = []
    loss_values_v = []
    check = 0; accuracy_past = 0
    for epoch in range(1, num_epochs + 1):
        #---------------------- 모델 학습 ---------------------#
        model.train()
        batch_number = 0
        running_loss = 0.0
        for batch_idx, samples in enumerate(train_dataloader):
            x_train, y_train = samples

            # 변수 초기화
            optimizer.zero_grad()
            y_hat = model.forward(x_train)
            loss = criterion(y_hat,y_train.long())
            # 모델의 파라미터와 관련된 loss의 그래디언트 계산
            loss.backward()
            # 신경망 가중치(parameter) 업데이트
            optimizer.step()

            running_loss += loss.item()
            batch_number += 1
        loss_values.append(running_loss / batch_number)
        #------------------------------------------------------#

        #---------------------- 모델 검증 ---------------------#
        model.eval()
        accuracy = 0.0
        total = 0.0
        for batch_idx, data in enumerate(valid_dataloader):
            x_valid, y_valid = data

            v_hat = model.forward(x_valid)
            v_loss = criterion(v_hat,y_valid.long())

            _, predicted = torch.max(v_hat.data, 1)
            total += y_valid.size(0)
            accuracy += (predicted == y_valid).sum().item()
        loss_values_v.append(loss.item())
        accuracy = (accuracy / total)
        #------------------------------------------------------#
        # Check for early stopping

        if epoch % 1 == 0:
            print('[Epoch {}/{}] [Train_Loss: {:.6f} /Valid_Loss: {:.6f}]'.format(epoch, num_epochs, loss.item(),v_loss.item()))
            print('[Epoch {}/{}] [Accuracy  : {:.6f}]'.format(epoch, num_epochs, accuracy))

        if accuracy_past > accuracy:
            check += 1
        else:
            check = 0
            accuracy_past = accuracy

        if check > 50:
            print('This is time to do early stopping')
            break

    torch.save(model, PATH + 'model.pt')
    print("모델 저장:", PATH + 'model.pt')
    return loss_values, loss_values_v

# %% [markdown]
# ### 4-1. 심층신경망 (DNN) 모델 학습

# %% [markdown]
# ### 4-2. 합성곱신경망 (CNN) 모델 학습

# %% [markdown]
# ### 4-3. 순환신경망 (RNN) 모델 학습

# %% [markdown]
# ## 5. 모델 평가

# %% [markdown]
# #### 모델 평가

# %%
def test_model(model, PATH):
    model = torch.load(PATH + 'model.pt')
    #---------------------- 모델 시험 ---------------------#
    model.eval()
    total = 0.0
    accuracy = 0.0
    for batch_idx, data in enumerate(test_dataloader):
        x_test, y_test = data

        t_hat = model(x_test)
        _, predicted = torch.max(t_hat.data, 1)
        total += y_test.size(0)
        accuracy += (predicted == y_test).sum().item()
    accuracy = (accuracy / total)
    #------------------------------------------------------#
    print(accuracy)

# %% [markdown]
# #### 혼동 행렬 (Confusion matrix)

# %%
from sklearn.metrics import classification_report, confusion_matrix

def draw_confusion_matrix(model, xt, yt, PATH):
    y_pred = []; y_true = []

    model.eval()
    y_hat = model(xt)
    output = (torch.max(torch.exp(y_hat), 1)[1]).data.cpu().numpy()
    y_pred.extend(output) # Save Prediction

    labels = y_test.data.cpu().numpy()
    y_true.extend(labels) # Save Truth

    # 분류 항목
    classes = ('Normal', 'Type1', 'Type2', 'Type3')

    # Confussion Matrix 생성
    plt.figure(figsize = (7,5))
    dlen = float(len(x_test)) # test data 크기 : 여기서는 80000

    cm = confusion_matrix(y_true, y_pred)
    df_cm = pd.DataFrame(cm/dlen, index = [i for i in classes],columns = [i for i in classes])

    # annot : 각 셀의 데이터 값을 나타내는 옵션
    sns.heatmap(df_cm, annot=True, cmap=plt.cm.Blues)
    plt.title("Confusion Matrix", size=24, fontweight='bold')
    plt.xlabel("Predicted Label", size=16); plt.ylabel("Actual Label", size=16)
    # 각 축의 font 조정
    plt.rc('xtick', labelsize=12); plt.rc('ytick', labelsize=12); plt.yticks(rotation=0)
    # 결과 저장
    plt.savefig(PATH + 'cm_output.png')

# %% [markdown]
# #### 손실(Loss) 그래프

# %%
def plot_loss_graph(loss_values, loss_values_v):
    plt.figure()
    plt.plot(loss_values)
    plt.plot(loss_values_v)
    plt.title("Training & Validation Loss")
    plt.ylabel("loss", fontsize="large")
    plt.xlabel("epoch", fontsize="large")
    plt.legend(["train", "validation"])
    plt.tight_layout()
    # 결과 저장
    plt.savefig(PATH + 'lossplot_output.png')

# %% [markdown]
# ### 5-1. 심층신경망 (DNN) 모델 성능 평가

# %%
# pytorch version : 1.9.0 (버전에 따라 아래 코드가 실행되지 않을 수 있으니 requirement.txt의 버전대로 설치해주세요)

DNN_model = KAMP_DNN()
num_epochs = 1000
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(DNN_model.parameters())
PATH = dir+'dnn_'

DNN_loss_values, DNN_loss_values_v = train_model(DNN_model, criterion, optimizer, num_epochs, train_dataloader, PATH)
# Out:
# [Epoch 1/1000] [Train_Loss: 1.146377 /Valid_Loss: 1.094635]
# [Epoch 1/1000] [Accuracy  : 0.446250]
# [Epoch 2/1000] [Train_Loss: 0.915355 /Valid_Loss: 0.885529]
# [Epoch 2/1000] [Accuracy  : 0.492625]
# [Epoch 3/1000] [Train_Loss: 0.888713 /Valid_Loss: 0.853352]
# [Epoch 3/1000] [Accuracy  : 0.486100]
# [Epoch 4/1000] [Train_Loss: 0.867756 /Valid_Loss: 0.844132]
# [Epoch 4/1000] [Accuracy  : 0.497912]
# [Epoch 5/1000] [Train_Loss: 0.878113 /Valid_Loss: 0.835231]
# [Epoch 5/1000] [Accuracy  : 0.513112]
# [Epoch 6/1000] [Train_Loss: 0.850133 /Valid_Loss: 0.821029]
# [Epoch 6/1000] [Accuracy  : 0.544775]
# [Epoch 7/1000] [Train_Loss: 0.828580 /Valid_Loss: 0.799291]
# [Epoch 7/1000] [Accuracy  : 0.580375]
# [Epoch 8/1000] [Train_Loss: 0.809893 /Valid_Loss: 0.775063]
# [Epoch 8/1000] [Accuracy  : 0.613363]
# [Epoch 9/1000] [Train_Loss: 0.769995 /Valid_Loss: 0.750189]
# [Epoch 9/1000] [Accuracy  : 0.629600]
# [Epoch 10/1000] [Train_Loss: 0.764847 /Valid_Loss: 0.729709]
# [Epoch 10/1000] [Accuracy  : 0.638938]
# [Epoch 11/1000] [Train_Loss: 0.765112 /Valid_Loss: 0.718325]
# [Epoch 11/1000] [Accuracy  : 0.648613]
# [Epoch 12/1000] [Train_Loss: 0.741858 /Valid_Loss: 0.704757]
# [Epoch 12/1000] [Accuracy  : 0.659038]
# [Epoch 13/1000] [Train_Loss: 0.730907 /Valid_Loss: 0.699916]
# [Epoch 13/1000] [Accuracy  : 0.656450]
# [Epoch 14/1000] [Train_Loss: 0.718541 /Valid_Loss: 0.695459]
# [Epoch 14/1000] [Accuracy  : 0.658725]
# [Epoch 15/1000] [Train_Loss: 0.697850 /Valid_Loss: 0.691842]
# [Epoch 15/1000] [Accuracy  : 0.658963]
# [Epoch 16/1000] [Train_Loss: 0.694320 /Valid_Loss: 0.682718]
# [Epoch 16/1000] [Accuracy  : 0.668600]
# [Epoch 17/1000] [Train_Loss: 0.681996 /Valid_Loss: 0.676497]
# [Epoch 17/1000] [Accuracy  : 0.670425]
# [Epoch 18/1000] [Train_Loss: 0.699503 /Valid_Loss: 0.671407]
# [Epoch 18/1000] [Accuracy  : 0.674925]
# [Epoch 19/1000] [Train_Loss: 0.689446 /Valid_Loss: 0.666247]
# [Epoch 19/1000] [Accuracy  : 0.675763]
# [Epoch 20/1000] [Train_Loss: 0.665276 /Valid_Loss: 0.663386]
# [Epoch 20/1000] [Accuracy  : 0.678525]
# [Epoch 21/1000] [Train_Loss: 0.662573 /Valid_Loss: 0.660892]
# [Epoch 21/1000] [Accuracy  : 0.677412]
# [Epoch 22/1000] [Train_Loss: 0.674618 /Valid_Loss: 0.652926]
# [Epoch 22/1000] [Accuracy  : 0.692562]
# [Epoch 23/1000] [Train_Loss: 0.656303 /Valid_Loss: 0.649936]
# [Epoch 23/1000] [Accuracy  : 0.693887]
# [Epoch 24/1000] [Train_Loss: 0.648362 /Valid_Loss: 0.645092]
# [Epoch 24/1000] [Accuracy  : 0.704450]
# [Epoch 25/1000] [Train_Loss: 0.650143 /Valid_Loss: 0.645858]
# [Epoch 25/1000] [Accuracy  : 0.703275]
# [Epoch 26/1000] [Train_Loss: 0.650058 /Valid_Loss: 0.638071]
# [Epoch 26/1000] [Accuracy  : 0.708400]
# [Epoch 27/1000] [Train_Loss: 0.656872 /Valid_Loss: 0.642661]
# [Epoch 27/1000] [Accuracy  : 0.700937]
# [Epoch 28/1000] [Train_Loss: 0.636430 /Valid_Loss: 0.634237]
# [Epoch 28/1000] [Accuracy  : 0.710938]
# [Epoch 29/1000] [Train_Loss: 0.614547 /Valid_Loss: 0.630825]
# [Epoch 29/1000] [Accuracy  : 0.710287]
# [Epoch 30/1000] [Train_Loss: 0.624267 /Valid_Loss: 0.627939]
# [Epoch 30/1000] [Accuracy  : 0.713488]
# [Epoch 31/1000] [Train_Loss: 0.609513 /Valid_Loss: 0.628560]
# [Epoch 31/1000] [Accuracy  : 0.709588]
# [Epoch 32/1000] [Train_Loss: 0.633568 /Valid_Loss: 0.629795]
# [Epoch 32/1000] [Accuracy  : 0.710425]
# [Epoch 33/1000] [Train_Loss: 0.624125 /Valid_Loss: 0.623583]
# [Epoch 33/1000] [Accuracy  : 0.714688]
# [Epoch 34/1000] [Train_Loss: 0.599737 /Valid_Loss: 0.625686]
# [Epoch 34/1000] [Accuracy  : 0.710875]
# [Epoch 35/1000] [Train_Loss: 0.617187 /Valid_Loss: 0.623335]
# [Epoch 35/1000] [Accuracy  : 0.712788]
# [Epoch 36/1000] [Train_Loss: 0.613387 /Valid_Loss: 0.624279]
# [Epoch 36/1000] [Accuracy  : 0.709263]
# [Epoch 37/1000] [Train_Loss: 0.594052 /Valid_Loss: 0.617421]
# [Epoch 37/1000] [Accuracy  : 0.716875]
# [Epoch 38/1000] [Train_Loss: 0.620474 /Valid_Loss: 0.617031]
# [Epoch 38/1000] [Accuracy  : 0.718025]
# [Epoch 39/1000] [Train_Loss: 0.616846 /Valid_Loss: 0.613790]
# [Epoch 39/1000] [Accuracy  : 0.723463]
# [Epoch 40/1000] [Train_Loss: 0.604772 /Valid_Loss: 0.611484]
# [Epoch 40/1000] [Accuracy  : 0.722437]
# [Epoch 41/1000] [Train_Loss: 0.597895 /Valid_Loss: 0.613581]
# [Epoch 41/1000] [Accuracy  : 0.721788]
# [Epoch 42/1000] [Train_Loss: 0.614185 /Valid_Loss: 0.613841]
# [Epoch 42/1000] [Accuracy  : 0.718363]
# [Epoch 43/1000] [Train_Loss: 0.599684 /Valid_Loss: 0.614638]
# [Epoch 43/1000] [Accuracy  : 0.717838]
# [Epoch 44/1000] [Train_Loss: 0.596772 /Valid_Loss: 0.609493]
# [Epoch 44/1000] [Accuracy  : 0.724175]
# [Epoch 45/1000] [Train_Loss: 0.604701 /Valid_Loss: 0.611078]
# [Epoch 45/1000] [Accuracy  : 0.723950]
# [Epoch 46/1000] [Train_Loss: 0.593359 /Valid_Loss: 0.609064]
# [Epoch 46/1000] [Accuracy  : 0.722375]
# [Epoch 47/1000] [Train_Loss: 0.581937 /Valid_Loss: 0.613926]
# [Epoch 47/1000] [Accuracy  : 0.721838]
# [Epoch 48/1000] [Train_Loss: 0.594458 /Valid_Loss: 0.611201]
# [Epoch 48/1000] [Accuracy  : 0.722350]
# [Epoch 49/1000] [Train_Loss: 0.580375 /Valid_Loss: 0.606909]
# [Epoch 49/1000] [Accuracy  : 0.725875]
# [Epoch 50/1000] [Train_Loss: 0.588866 /Valid_Loss: 0.605721]
# [Epoch 50/1000] [Accuracy  : 0.726788]
# [Epoch 51/1000] [Train_Loss: 0.570182 /Valid_Loss: 0.606199]
# [Epoch 51/1000] [Accuracy  : 0.724850]
# [Epoch 52/1000] [Train_Loss: 0.594104 /Valid_Loss: 0.609299]
# [Epoch 52/1000] [Accuracy  : 0.720638]
# [Epoch 53/1000] [Train_Loss: 0.598614 /Valid_Loss: 0.599505]
# [Epoch 53/1000] [Accuracy  : 0.730850]
# [Epoch 54/1000] [Train_Loss: 0.585358 /Valid_Loss: 0.605788]
# [Epoch 54/1000] [Accuracy  : 0.726650]
# [Epoch 55/1000] [Train_Loss: 0.582824 /Valid_Loss: 0.603187]
# [Epoch 55/1000] [Accuracy  : 0.726962]
# [Epoch 56/1000] [Train_Loss: 0.572394 /Valid_Loss: 0.603518]
# [Epoch 56/1000] [Accuracy  : 0.729463]
# [Epoch 57/1000] [Train_Loss: 0.574613 /Valid_Loss: 0.600061]
# [Epoch 57/1000] [Accuracy  : 0.728712]
# [Epoch 58/1000] [Train_Loss: 0.567785 /Valid_Loss: 0.598744]
# [Epoch 58/1000] [Accuracy  : 0.729225]
# [Epoch 59/1000] [Train_Loss: 0.589465 /Valid_Loss: 0.601553]
# [Epoch 59/1000] [Accuracy  : 0.728537]
# [Epoch 60/1000] [Train_Loss: 0.574484 /Valid_Loss: 0.598592]
# [Epoch 60/1000] [Accuracy  : 0.731587]
# [Epoch 61/1000] [Train_Loss: 0.589013 /Valid_Loss: 0.597982]
# [Epoch 61/1000] [Accuracy  : 0.729250]
# [Epoch 62/1000] [Train_Loss: 0.560391 /Valid_Loss: 0.597402]
# [Epoch 62/1000] [Accuracy  : 0.728437]
# [Epoch 63/1000] [Train_Loss: 0.590388 /Valid_Loss: 0.593870]
# [Epoch 63/1000] [Accuracy  : 0.734600]
# [Epoch 64/1000] [Train_Loss: 0.571837 /Valid_Loss: 0.601071]
# [Epoch 64/1000] [Accuracy  : 0.727662]
# [Epoch 65/1000] [Train_Loss: 0.578322 /Valid_Loss: 0.596472]
# [Epoch 65/1000] [Accuracy  : 0.730825]
# [Epoch 66/1000] [Train_Loss: 0.560761 /Valid_Loss: 0.591879]
# [Epoch 66/1000] [Accuracy  : 0.734275]
# [Epoch 67/1000] [Train_Loss: 0.566885 /Valid_Loss: 0.593504]
# [Epoch 67/1000] [Accuracy  : 0.732363]
# [Epoch 68/1000] [Train_Loss: 0.588349 /Valid_Loss: 0.593542]
# [Epoch 68/1000] [Accuracy  : 0.731788]
# [Epoch 69/1000] [Train_Loss: 0.559373 /Valid_Loss: 0.595096]
# [Epoch 69/1000] [Accuracy  : 0.731537]
# [Epoch 70/1000] [Train_Loss: 0.580959 /Valid_Loss: 0.597519]
# [Epoch 70/1000] [Accuracy  : 0.730675]
# [Epoch 71/1000] [Train_Loss: 0.561214 /Valid_Loss: 0.591651]
# [Epoch 71/1000] [Accuracy  : 0.733275]
# [Epoch 72/1000] [Train_Loss: 0.569956 /Valid_Loss: 0.591600]
# [Epoch 72/1000] [Accuracy  : 0.734350]
# [Epoch 73/1000] [Train_Loss: 0.569551 /Valid_Loss: 0.590843]
# [Epoch 73/1000] [Accuracy  : 0.733375]
# [Epoch 74/1000] [Train_Loss: 0.558790 /Valid_Loss: 0.594844]
# [Epoch 74/1000] [Accuracy  : 0.731100]
# [Epoch 75/1000] [Train_Loss: 0.551027 /Valid_Loss: 0.596184]
# [Epoch 75/1000] [Accuracy  : 0.727900]
# [Epoch 76/1000] [Train_Loss: 0.560817 /Valid_Loss: 0.589718]
# [Epoch 76/1000] [Accuracy  : 0.736112]
# [Epoch 77/1000] [Train_Loss: 0.561017 /Valid_Loss: 0.595301]
# [Epoch 77/1000] [Accuracy  : 0.728075]
# [Epoch 78/1000] [Train_Loss: 0.569786 /Valid_Loss: 0.590793]
# [Epoch 78/1000] [Accuracy  : 0.734912]
# [Epoch 79/1000] [Train_Loss: 0.567572 /Valid_Loss: 0.588313]
# [Epoch 79/1000] [Accuracy  : 0.736375]
# [Epoch 80/1000] [Train_Loss: 0.550469 /Valid_Loss: 0.593228]
# [Epoch 80/1000] [Accuracy  : 0.730038]
# [Epoch 81/1000] [Train_Loss: 0.562172 /Valid_Loss: 0.592615]
# [Epoch 81/1000] [Accuracy  : 0.733788]
# [Epoch 82/1000] [Train_Loss: 0.565209 /Valid_Loss: 0.587553]
# [Epoch 82/1000] [Accuracy  : 0.735988]
# [Epoch 83/1000] [Train_Loss: 0.544417 /Valid_Loss: 0.591930]
# [Epoch 83/1000] [Accuracy  : 0.732500]
# [Epoch 84/1000] [Train_Loss: 0.545290 /Valid_Loss: 0.587532]
# [Epoch 84/1000] [Accuracy  : 0.735775]
# [Epoch 85/1000] [Train_Loss: 0.557325 /Valid_Loss: 0.589585]
# [Epoch 85/1000] [Accuracy  : 0.732738]
# [Epoch 86/1000] [Train_Loss: 0.567218 /Valid_Loss: 0.583171]
# [Epoch 86/1000] [Accuracy  : 0.738225]
# [Epoch 87/1000] [Train_Loss: 0.557810 /Valid_Loss: 0.592889]
# [Epoch 87/1000] [Accuracy  : 0.732875]
# [Epoch 88/1000] [Train_Loss: 0.558484 /Valid_Loss: 0.587096]
# [Epoch 88/1000] [Accuracy  : 0.735688]
# [Epoch 89/1000] [Train_Loss: 0.548287 /Valid_Loss: 0.589880]
# [Epoch 89/1000] [Accuracy  : 0.733200]
# [Epoch 90/1000] [Train_Loss: 0.543417 /Valid_Loss: 0.585612]
# [Epoch 90/1000] [Accuracy  : 0.736925]
# [Epoch 91/1000] [Train_Loss: 0.547157 /Valid_Loss: 0.585040]
# [Epoch 91/1000] [Accuracy  : 0.738050]
# [Epoch 92/1000] [Train_Loss: 0.554716 /Valid_Loss: 0.585993]
# [Epoch 92/1000] [Accuracy  : 0.736112]
# [Epoch 93/1000] [Train_Loss: 0.561580 /Valid_Loss: 0.583380]
# [Epoch 93/1000] [Accuracy  : 0.737475]
# [Epoch 94/1000] [Train_Loss: 0.549930 /Valid_Loss: 0.584587]
# [Epoch 94/1000] [Accuracy  : 0.738625]
# [Epoch 95/1000] [Train_Loss: 0.565434 /Valid_Loss: 0.582303]
# [Epoch 95/1000] [Accuracy  : 0.739988]
# [Epoch 96/1000] [Train_Loss: 0.550606 /Valid_Loss: 0.586037]
# [Epoch 96/1000] [Accuracy  : 0.737062]
# [Epoch 97/1000] [Train_Loss: 0.546930 /Valid_Loss: 0.582289]
# [Epoch 97/1000] [Accuracy  : 0.739625]
# [Epoch 98/1000] [Train_Loss: 0.570723 /Valid_Loss: 0.582863]
# [Epoch 98/1000] [Accuracy  : 0.736875]
# [Epoch 99/1000] [Train_Loss: 0.547495 /Valid_Loss: 0.587118]
# [Epoch 99/1000] [Accuracy  : 0.733775]
# [Epoch 100/1000] [Train_Loss: 0.541969 /Valid_Loss: 0.588021]
# [Epoch 100/1000] [Accuracy  : 0.734625]
# [Epoch 101/1000] [Train_Loss: 0.584032 /Valid_Loss: 0.586563]
# [Epoch 101/1000] [Accuracy  : 0.738525]
# [Epoch 102/1000] [Train_Loss: 0.571387 /Valid_Loss: 0.587506]
# [Epoch 102/1000] [Accuracy  : 0.734413]
# [Epoch 103/1000] [Train_Loss: 0.543672 /Valid_Loss: 0.585836]
# [Epoch 103/1000] [Accuracy  : 0.736950]
# [Epoch 104/1000] [Train_Loss: 0.556159 /Valid_Loss: 0.587156]
# [Epoch 104/1000] [Accuracy  : 0.734988]
# [Epoch 105/1000] [Train_Loss: 0.564363 /Valid_Loss: 0.588031]
# [Epoch 105/1000] [Accuracy  : 0.735825]
# [Epoch 106/1000] [Train_Loss: 0.555925 /Valid_Loss: 0.587994]
# [Epoch 106/1000] [Accuracy  : 0.735988]
# [Epoch 107/1000] [Train_Loss: 0.564944 /Valid_Loss: 0.588765]
# [Epoch 107/1000] [Accuracy  : 0.735175]
# [Epoch 108/1000] [Train_Loss: 0.558158 /Valid_Loss: 0.588265]
# [Epoch 108/1000] [Accuracy  : 0.737400]
# [Epoch 109/1000] [Train_Loss: 0.564215 /Valid_Loss: 0.585044]
# [Epoch 109/1000] [Accuracy  : 0.736725]
# [Epoch 110/1000] [Train_Loss: 0.554595 /Valid_Loss: 0.588122]
# [Epoch 110/1000] [Accuracy  : 0.735450]
# [Epoch 111/1000] [Train_Loss: 0.555310 /Valid_Loss: 0.582201]
# [Epoch 111/1000] [Accuracy  : 0.740237]
# [Epoch 112/1000] [Train_Loss: 0.546215 /Valid_Loss: 0.581730]
# [Epoch 112/1000] [Accuracy  : 0.739287]
# [Epoch 113/1000] [Train_Loss: 0.543179 /Valid_Loss: 0.585146]
# [Epoch 113/1000] [Accuracy  : 0.734925]
# [Epoch 114/1000] [Train_Loss: 0.563766 /Valid_Loss: 0.584029]
# [Epoch 114/1000] [Accuracy  : 0.738600]
# [Epoch 115/1000] [Train_Loss: 0.553839 /Valid_Loss: 0.584947]
# [Epoch 115/1000] [Accuracy  : 0.737888]
# [Epoch 116/1000] [Train_Loss: 0.550048 /Valid_Loss: 0.583084]
# [Epoch 116/1000] [Accuracy  : 0.737762]
# [Epoch 117/1000] [Train_Loss: 0.553837 /Valid_Loss: 0.583161]
# [Epoch 117/1000] [Accuracy  : 0.737487]
# [Epoch 118/1000] [Train_Loss: 0.565788 /Valid_Loss: 0.582435]
# [Epoch 118/1000] [Accuracy  : 0.738575]
# [Epoch 119/1000] [Train_Loss: 0.546191 /Valid_Loss: 0.587074]
# [Epoch 119/1000] [Accuracy  : 0.735550]
# [Epoch 120/1000] [Train_Loss: 0.551681 /Valid_Loss: 0.588779]
# [Epoch 120/1000] [Accuracy  : 0.736325]
# [Epoch 121/1000] [Train_Loss: 0.543025 /Valid_Loss: 0.583887]
# [Epoch 121/1000] [Accuracy  : 0.736850]
# [Epoch 122/1000] [Train_Loss: 0.534218 /Valid_Loss: 0.588977]
# [Epoch 122/1000] [Accuracy  : 0.733487]
# [Epoch 123/1000] [Train_Loss: 0.551137 /Valid_Loss: 0.588515]
# [Epoch 123/1000] [Accuracy  : 0.734175]
# [Epoch 124/1000] [Train_Loss: 0.562061 /Valid_Loss: 0.585805]
# [Epoch 124/1000] [Accuracy  : 0.736587]
# [Epoch 125/1000] [Train_Loss: 0.557218 /Valid_Loss: 0.585692]
# [Epoch 125/1000] [Accuracy  : 0.735850]
# [Epoch 126/1000] [Train_Loss: 0.553443 /Valid_Loss: 0.588654]
# [Epoch 126/1000] [Accuracy  : 0.735725]
# [Epoch 127/1000] [Train_Loss: 0.535498 /Valid_Loss: 0.586327]
# [Epoch 127/1000] [Accuracy  : 0.735587]
# [Epoch 128/1000] [Train_Loss: 0.557402 /Valid_Loss: 0.586034]
# [Epoch 128/1000] [Accuracy  : 0.736313]
# [Epoch 129/1000] [Train_Loss: 0.543207 /Valid_Loss: 0.591045]
# [Epoch 129/1000] [Accuracy  : 0.736425]
# [Epoch 130/1000] [Train_Loss: 0.548941 /Valid_Loss: 0.586237]
# [Epoch 130/1000] [Accuracy  : 0.737263]
# [Epoch 131/1000] [Train_Loss: 0.561791 /Valid_Loss: 0.583346]
# [Epoch 131/1000] [Accuracy  : 0.739150]
# [Epoch 132/1000] [Train_Loss: 0.542295 /Valid_Loss: 0.585781]
# [Epoch 132/1000] [Accuracy  : 0.735938]
# [Epoch 133/1000] [Train_Loss: 0.542697 /Valid_Loss: 0.580700]
# [Epoch 133/1000] [Accuracy  : 0.742587]
# [Epoch 134/1000] [Train_Loss: 0.536584 /Valid_Loss: 0.586177]
# [Epoch 134/1000] [Accuracy  : 0.737513]
# [Epoch 135/1000] [Train_Loss: 0.555738 /Valid_Loss: 0.584169]
# [Epoch 135/1000] [Accuracy  : 0.739513]
# [Epoch 136/1000] [Train_Loss: 0.562100 /Valid_Loss: 0.587937]
# [Epoch 136/1000] [Accuracy  : 0.733900]
# [Epoch 137/1000] [Train_Loss: 0.555282 /Valid_Loss: 0.588024]
# [Epoch 137/1000] [Accuracy  : 0.736975]
# [Epoch 138/1000] [Train_Loss: 0.539848 /Valid_Loss: 0.589016]
# [Epoch 138/1000] [Accuracy  : 0.733712]
# [Epoch 139/1000] [Train_Loss: 0.535143 /Valid_Loss: 0.586765]
# [Epoch 139/1000] [Accuracy  : 0.738413]
# [Epoch 140/1000] [Train_Loss: 0.536530 /Valid_Loss: 0.580182]
# [Epoch 140/1000] [Accuracy  : 0.740888]
# [Epoch 141/1000] [Train_Loss: 0.547222 /Valid_Loss: 0.586614]
# [Epoch 141/1000] [Accuracy  : 0.737350]
# [Epoch 142/1000] [Train_Loss: 0.545339 /Valid_Loss: 0.587139]
# [Epoch 142/1000] [Accuracy  : 0.737688]
# [Epoch 143/1000] [Train_Loss: 0.542634 /Valid_Loss: 0.583871]
# [Epoch 143/1000] [Accuracy  : 0.740187]
# [Epoch 144/1000] [Train_Loss: 0.535299 /Valid_Loss: 0.584183]
# [Epoch 144/1000] [Accuracy  : 0.738200]
# [Epoch 145/1000] [Train_Loss: 0.540051 /Valid_Loss: 0.588922]
# [Epoch 145/1000] [Accuracy  : 0.736387]
# [Epoch 146/1000] [Train_Loss: 0.562315 /Valid_Loss: 0.581720]
# [Epoch 146/1000] [Accuracy  : 0.738387]
# [Epoch 147/1000] [Train_Loss: 0.548399 /Valid_Loss: 0.584722]
# [Epoch 147/1000] [Accuracy  : 0.741250]
# [Epoch 148/1000] [Train_Loss: 0.553657 /Valid_Loss: 0.584405]
# [Epoch 148/1000] [Accuracy  : 0.739437]
# [Epoch 149/1000] [Train_Loss: 0.542872 /Valid_Loss: 0.588303]
# [Epoch 149/1000] [Accuracy  : 0.737563]
# [Epoch 150/1000] [Train_Loss: 0.541850 /Valid_Loss: 0.587287]
# [Epoch 150/1000] [Accuracy  : 0.736475]
# [Epoch 151/1000] [Train_Loss: 0.546905 /Valid_Loss: 0.583837]
# [Epoch 151/1000] [Accuracy  : 0.739712]
# [Epoch 152/1000] [Train_Loss: 0.526445 /Valid_Loss: 0.585037]
# [Epoch 152/1000] [Accuracy  : 0.739387]
# [Epoch 153/1000] [Train_Loss: 0.549323 /Valid_Loss: 0.584532]
# [Epoch 153/1000] [Accuracy  : 0.739637]
# [Epoch 154/1000] [Train_Loss: 0.545822 /Valid_Loss: 0.580870]
# [Epoch 154/1000] [Accuracy  : 0.738888]
# [Epoch 155/1000] [Train_Loss: 0.550199 /Valid_Loss: 0.584874]
# [Epoch 155/1000] [Accuracy  : 0.738900]
# [Epoch 156/1000] [Train_Loss: 0.551317 /Valid_Loss: 0.585827]
# [Epoch 156/1000] [Accuracy  : 0.738088]
# [Epoch 157/1000] [Train_Loss: 0.535547 /Valid_Loss: 0.580550]
# [Epoch 157/1000] [Accuracy  : 0.739038]
# [Epoch 158/1000] [Train_Loss: 0.561095 /Valid_Loss: 0.582426]
# [Epoch 158/1000] [Accuracy  : 0.741138]
# [Epoch 159/1000] [Train_Loss: 0.559580 /Valid_Loss: 0.584314]
# [Epoch 159/1000] [Accuracy  : 0.737788]
# [Epoch 160/1000] [Train_Loss: 0.550188 /Valid_Loss: 0.582719]
# [Epoch 160/1000] [Accuracy  : 0.740350]
# [Epoch 161/1000] [Train_Loss: 0.521178 /Valid_Loss: 0.588881]
# [Epoch 161/1000] [Accuracy  : 0.737988]
# [Epoch 162/1000] [Train_Loss: 0.514691 /Valid_Loss: 0.584704]
# [Epoch 162/1000] [Accuracy  : 0.739750]
# [Epoch 163/1000] [Train_Loss: 0.547446 /Valid_Loss: 0.585416]
# [Epoch 163/1000] [Accuracy  : 0.739387]
# [Epoch 164/1000] [Train_Loss: 0.538009 /Valid_Loss: 0.585362]
# [Epoch 164/1000] [Accuracy  : 0.739788]
# [Epoch 165/1000] [Train_Loss: 0.533820 /Valid_Loss: 0.588661]
# [Epoch 165/1000] [Accuracy  : 0.739263]
# [Epoch 166/1000] [Train_Loss: 0.542457 /Valid_Loss: 0.582666]
# [Epoch 166/1000] [Accuracy  : 0.741150]
# [Epoch 167/1000] [Train_Loss: 0.557816 /Valid_Loss: 0.583980]
# [Epoch 167/1000] [Accuracy  : 0.737337]
# [Epoch 168/1000] [Train_Loss: 0.543149 /Valid_Loss: 0.584048]
# [Epoch 168/1000] [Accuracy  : 0.741350]
# [Epoch 169/1000] [Train_Loss: 0.557133 /Valid_Loss: 0.585954]
# [Epoch 169/1000] [Accuracy  : 0.738213]
# [Epoch 170/1000] [Train_Loss: 0.533636 /Valid_Loss: 0.585740]
# [Epoch 170/1000] [Accuracy  : 0.738062]
# [Epoch 171/1000] [Train_Loss: 0.527478 /Valid_Loss: 0.584378]
# [Epoch 171/1000] [Accuracy  : 0.740750]
# [Epoch 172/1000] [Train_Loss: 0.543466 /Valid_Loss: 0.584314]
# [Epoch 172/1000] [Accuracy  : 0.738788]
# [Epoch 173/1000] [Train_Loss: 0.531753 /Valid_Loss: 0.584048]
# [Epoch 173/1000] [Accuracy  : 0.742125]
# [Epoch 174/1000] [Train_Loss: 0.527893 /Valid_Loss: 0.587100]
# [Epoch 174/1000] [Accuracy  : 0.741138]
# [Epoch 175/1000] [Train_Loss: 0.539924 /Valid_Loss: 0.588889]
# [Epoch 175/1000] [Accuracy  : 0.737350]
# [Epoch 176/1000] [Train_Loss: 0.541457 /Valid_Loss: 0.585883]
# [Epoch 176/1000] [Accuracy  : 0.738463]
# [Epoch 177/1000] [Train_Loss: 0.546840 /Valid_Loss: 0.589387]
# [Epoch 177/1000] [Accuracy  : 0.736975]
# [Epoch 178/1000] [Train_Loss: 0.542830 /Valid_Loss: 0.593616]
# [Epoch 178/1000] [Accuracy  : 0.735587]
# [Epoch 179/1000] [Train_Loss: 0.540364 /Valid_Loss: 0.586490]
# [Epoch 179/1000] [Accuracy  : 0.738637]
# [Epoch 180/1000] [Train_Loss: 0.524678 /Valid_Loss: 0.585840]
# [Epoch 180/1000] [Accuracy  : 0.738650]
# [Epoch 181/1000] [Train_Loss: 0.533565 /Valid_Loss: 0.583619]
# [Epoch 181/1000] [Accuracy  : 0.740563]
# [Epoch 182/1000] [Train_Loss: 0.529054 /Valid_Loss: 0.583152]
# [Epoch 182/1000] [Accuracy  : 0.743038]
# [Epoch 183/1000] [Train_Loss: 0.547489 /Valid_Loss: 0.583965]
# [Epoch 183/1000] [Accuracy  : 0.740613]
# [Epoch 184/1000] [Train_Loss: 0.537320 /Valid_Loss: 0.588921]
# [Epoch 184/1000] [Accuracy  : 0.735350]
# [Epoch 185/1000] [Train_Loss: 0.544614 /Valid_Loss: 0.585433]
# [Epoch 185/1000] [Accuracy  : 0.737775]
# [Epoch 186/1000] [Train_Loss: 0.550990 /Valid_Loss: 0.586353]
# [Epoch 186/1000] [Accuracy  : 0.736275]
# [Epoch 187/1000] [Train_Loss: 0.546134 /Valid_Loss: 0.583033]
# [Epoch 187/1000] [Accuracy  : 0.742162]
# [Epoch 188/1000] [Train_Loss: 0.548284 /Valid_Loss: 0.590468]
# [Epoch 188/1000] [Accuracy  : 0.735325]
# [Epoch 189/1000] [Train_Loss: 0.548600 /Valid_Loss: 0.587501]
# [Epoch 189/1000] [Accuracy  : 0.738275]
# [Epoch 190/1000] [Train_Loss: 0.543405 /Valid_Loss: 0.581828]
# [Epoch 190/1000] [Accuracy  : 0.744463]
# [Epoch 191/1000] [Train_Loss: 0.535505 /Valid_Loss: 0.589905]
# [Epoch 191/1000] [Accuracy  : 0.738287]
# [Epoch 192/1000] [Train_Loss: 0.544905 /Valid_Loss: 0.585521]
# [Epoch 192/1000] [Accuracy  : 0.742325]
# [Epoch 193/1000] [Train_Loss: 0.552918 /Valid_Loss: 0.589138]
# [Epoch 193/1000] [Accuracy  : 0.735662]
# [Epoch 194/1000] [Train_Loss: 0.540217 /Valid_Loss: 0.585220]
# [Epoch 194/1000] [Accuracy  : 0.740812]
# [Epoch 195/1000] [Train_Loss: 0.562127 /Valid_Loss: 0.588310]
# [Epoch 195/1000] [Accuracy  : 0.736025]
# [Epoch 196/1000] [Train_Loss: 0.544622 /Valid_Loss: 0.587316]
# [Epoch 196/1000] [Accuracy  : 0.739213]
# [Epoch 197/1000] [Train_Loss: 0.543843 /Valid_Loss: 0.584430]
# [Epoch 197/1000] [Accuracy  : 0.738675]
# [Epoch 198/1000] [Train_Loss: 0.526342 /Valid_Loss: 0.590291]
# [Epoch 198/1000] [Accuracy  : 0.736000]
# [Epoch 199/1000] [Train_Loss: 0.560457 /Valid_Loss: 0.586982]
# [Epoch 199/1000] [Accuracy  : 0.741975]
# [Epoch 200/1000] [Train_Loss: 0.533507 /Valid_Loss: 0.588305]
# [Epoch 200/1000] [Accuracy  : 0.738375]
# [Epoch 201/1000] [Train_Loss: 0.556283 /Valid_Loss: 0.586694]
# [Epoch 201/1000] [Accuracy  : 0.736788]
# [Epoch 202/1000] [Train_Loss: 0.525839 /Valid_Loss: 0.591027]
# [Epoch 202/1000] [Accuracy  : 0.737075]
# [Epoch 203/1000] [Train_Loss: 0.526343 /Valid_Loss: 0.590734]
# [Epoch 203/1000] [Accuracy  : 0.737075]
# [Epoch 204/1000] [Train_Loss: 0.534856 /Valid_Loss: 0.592251]
# [Epoch 204/1000] [Accuracy  : 0.738425]
# [Epoch 205/1000] [Train_Loss: 0.535548 /Valid_Loss: 0.587022]
# [Epoch 205/1000] [Accuracy  : 0.738950]
# [Epoch 206/1000] [Train_Loss: 0.543073 /Valid_Loss: 0.582198]
# [Epoch 206/1000] [Accuracy  : 0.742600]
# [Epoch 207/1000] [Train_Loss: 0.545676 /Valid_Loss: 0.586994]
# [Epoch 207/1000] [Accuracy  : 0.739637]
# [Epoch 208/1000] [Train_Loss: 0.530933 /Valid_Loss: 0.589318]
# [Epoch 208/1000] [Accuracy  : 0.736387]
# [Epoch 209/1000] [Train_Loss: 0.518728 /Valid_Loss: 0.586822]
# [Epoch 209/1000] [Accuracy  : 0.737337]
# [Epoch 210/1000] [Train_Loss: 0.525757 /Valid_Loss: 0.590211]
# [Epoch 210/1000] [Accuracy  : 0.735487]
# [Epoch 211/1000] [Train_Loss: 0.544041 /Valid_Loss: 0.588454]
# [Epoch 211/1000] [Accuracy  : 0.737375]
# [Epoch 212/1000] [Train_Loss: 0.546733 /Valid_Loss: 0.587764]
# [Epoch 212/1000] [Accuracy  : 0.736688]
# [Epoch 213/1000] [Train_Loss: 0.537988 /Valid_Loss: 0.588036]
# [Epoch 213/1000] [Accuracy  : 0.736788]
# [Epoch 214/1000] [Train_Loss: 0.543757 /Valid_Loss: 0.581789]
# [Epoch 214/1000] [Accuracy  : 0.743050]
# [Epoch 215/1000] [Train_Loss: 0.517350 /Valid_Loss: 0.585425]
# [Epoch 215/1000] [Accuracy  : 0.736738]
# [Epoch 216/1000] [Train_Loss: 0.535066 /Valid_Loss: 0.591325]
# [Epoch 216/1000] [Accuracy  : 0.735800]
# [Epoch 217/1000] [Train_Loss: 0.536026 /Valid_Loss: 0.584742]
# [Epoch 217/1000] [Accuracy  : 0.739112]
# [Epoch 218/1000] [Train_Loss: 0.530564 /Valid_Loss: 0.588649]
# [Epoch 218/1000] [Accuracy  : 0.736325]
# [Epoch 219/1000] [Train_Loss: 0.537309 /Valid_Loss: 0.589264]
# [Epoch 219/1000] [Accuracy  : 0.736537]
# [Epoch 220/1000] [Train_Loss: 0.542721 /Valid_Loss: 0.590651]
# [Epoch 220/1000] [Accuracy  : 0.737088]
# [Epoch 221/1000] [Train_Loss: 0.535700 /Valid_Loss: 0.588990]
# [Epoch 221/1000] [Accuracy  : 0.735725]
# [Epoch 222/1000] [Train_Loss: 0.532074 /Valid_Loss: 0.589013]
# [Epoch 222/1000] [Accuracy  : 0.737112]
# [Epoch 223/1000] [Train_Loss: 0.523596 /Valid_Loss: 0.587613]
# [Epoch 223/1000] [Accuracy  : 0.738912]
# [Epoch 224/1000] [Train_Loss: 0.532645 /Valid_Loss: 0.585987]
# [Epoch 224/1000] [Accuracy  : 0.740738]
# [Epoch 225/1000] [Train_Loss: 0.526536 /Valid_Loss: 0.586776]
# [Epoch 225/1000] [Accuracy  : 0.737962]
# [Epoch 226/1000] [Train_Loss: 0.525418 /Valid_Loss: 0.587107]
# [Epoch 226/1000] [Accuracy  : 0.740213]
# [Epoch 227/1000] [Train_Loss: 0.528338 /Valid_Loss: 0.582092]
# [Epoch 227/1000] [Accuracy  : 0.740650]
# [Epoch 228/1000] [Train_Loss: 0.516617 /Valid_Loss: 0.587527]
# [Epoch 228/1000] [Accuracy  : 0.737750]
# [Epoch 229/1000] [Train_Loss: 0.535615 /Valid_Loss: 0.589780]
# [Epoch 229/1000] [Accuracy  : 0.735800]
# [Epoch 230/1000] [Train_Loss: 0.526849 /Valid_Loss: 0.581719]
# [Epoch 230/1000] [Accuracy  : 0.742762]
# [Epoch 231/1000] [Train_Loss: 0.550749 /Valid_Loss: 0.589753]
# [Epoch 231/1000] [Accuracy  : 0.737550]
# [Epoch 232/1000] [Train_Loss: 0.529641 /Valid_Loss: 0.587416]
# [Epoch 232/1000] [Accuracy  : 0.735075]
# [Epoch 233/1000] [Train_Loss: 0.541125 /Valid_Loss: 0.584155]
# [Epoch 233/1000] [Accuracy  : 0.741300]
# [Epoch 234/1000] [Train_Loss: 0.529242 /Valid_Loss: 0.586116]
# [Epoch 234/1000] [Accuracy  : 0.738025]
# [Epoch 235/1000] [Train_Loss: 0.522388 /Valid_Loss: 0.590587]
# [Epoch 235/1000] [Accuracy  : 0.733788]
# [Epoch 236/1000] [Train_Loss: 0.532905 /Valid_Loss: 0.589561]
# [Epoch 236/1000] [Accuracy  : 0.739537]
# [Epoch 237/1000] [Train_Loss: 0.542976 /Valid_Loss: 0.587593]
# [Epoch 237/1000] [Accuracy  : 0.740112]
# [Epoch 238/1000] [Train_Loss: 0.540731 /Valid_Loss: 0.588030]
# [Epoch 238/1000] [Accuracy  : 0.737200]
# [Epoch 239/1000] [Train_Loss: 0.532654 /Valid_Loss: 0.589468]
# [Epoch 239/1000] [Accuracy  : 0.737587]
# [Epoch 240/1000] [Train_Loss: 0.537902 /Valid_Loss: 0.585621]
# [Epoch 240/1000] [Accuracy  : 0.741250]
# [Epoch 241/1000] [Train_Loss: 0.513949 /Valid_Loss: 0.582589]
# [Epoch 241/1000] [Accuracy  : 0.741862]
# This is time to do early stopping
# 모델 저장: /content/gdrive/My Drive/Colab Notebooks/ai_mfg/rotor/dnn_model.pt

# %% [markdown]
# #### (1) 모델 평가

# %%
PATH = dir+'dnn_'
test_model(DNN_model, PATH)
# Out:
# 0.759825

# %% [markdown]
# #### (2) 혼동 행렬 (Confusion matrix)

# %%
draw_confusion_matrix(DNN_model, x_test, y_test, PATH)

# %% [markdown]
# #### (3) 손실(Loss) 그래프

# %%
plot_loss_graph(DNN_loss_values, DNN_loss_values_v)

# %% [markdown]
# ### 5-2. 합성곱신경망 (CNN) 모델  성능 평가

# %%
# pytorch version : 1.9.0 (버전에 따라 아래 코드가 실행되지 않을 수 있으니 requirement.txt의 버전대로 설치해주세요)

CNN_model = KAMP_CNN()
num_epochs = 1000
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(CNN_model.parameters())
PATH = dir+'cnn_'

CNN_loss_values, CNN_loss_values_v = train_model(CNN_model, criterion, optimizer, num_epochs, train_dataloader, PATH)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:306: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:1008.)
#   return F.conv1d(input, weight, bias, self.stride,
# [Epoch 1/1000] [Train_Loss: 1.293520 /Valid_Loss: 1.335396]
# [Epoch 1/1000] [Accuracy  : 0.468650]
# [Epoch 2/1000] [Train_Loss: 1.218684 /Valid_Loss: 1.208659]
# [Epoch 2/1000] [Accuracy  : 0.511537]
# [Epoch 3/1000] [Train_Loss: 1.149178 /Valid_Loss: 1.134233]
# [Epoch 3/1000] [Accuracy  : 0.565037]
# [Epoch 4/1000] [Train_Loss: 1.096355 /Valid_Loss: 1.085770]
# [Epoch 4/1000] [Accuracy  : 0.571313]
# [Epoch 5/1000] [Train_Loss: 1.049187 /Valid_Loss: 1.041038]
# [Epoch 5/1000] [Accuracy  : 0.573300]
# [Epoch 6/1000] [Train_Loss: 1.003405 /Valid_Loss: 0.998318]
# [Epoch 6/1000] [Accuracy  : 0.581250]
# [Epoch 7/1000] [Train_Loss: 0.969859 /Valid_Loss: 0.963946]
# [Epoch 7/1000] [Accuracy  : 0.576588]
# [Epoch 8/1000] [Train_Loss: 0.948025 /Valid_Loss: 0.939546]
# [Epoch 8/1000] [Accuracy  : 0.586538]
# [Epoch 9/1000] [Train_Loss: 0.932457 /Valid_Loss: 0.914305]
# [Epoch 9/1000] [Accuracy  : 0.591450]
# [Epoch 10/1000] [Train_Loss: 0.900191 /Valid_Loss: 0.889478]
# [Epoch 10/1000] [Accuracy  : 0.600912]
# [Epoch 11/1000] [Train_Loss: 0.880219 /Valid_Loss: 0.865290]
# [Epoch 11/1000] [Accuracy  : 0.602838]
# [Epoch 12/1000] [Train_Loss: 0.854581 /Valid_Loss: 0.846622]
# [Epoch 12/1000] [Accuracy  : 0.614912]
# [Epoch 13/1000] [Train_Loss: 0.844940 /Valid_Loss: 0.832880]
# [Epoch 13/1000] [Accuracy  : 0.622050]
# [Epoch 14/1000] [Train_Loss: 0.824010 /Valid_Loss: 0.804838]
# [Epoch 14/1000] [Accuracy  : 0.624088]
# [Epoch 15/1000] [Train_Loss: 0.805014 /Valid_Loss: 0.786504]
# [Epoch 15/1000] [Accuracy  : 0.631988]
# [Epoch 16/1000] [Train_Loss: 0.781816 /Valid_Loss: 0.768775]
# [Epoch 16/1000] [Accuracy  : 0.638825]
# [Epoch 17/1000] [Train_Loss: 0.767324 /Valid_Loss: 0.755090]
# [Epoch 17/1000] [Accuracy  : 0.640125]
# [Epoch 18/1000] [Train_Loss: 0.764854 /Valid_Loss: 0.747438]
# [Epoch 18/1000] [Accuracy  : 0.658537]
# [Epoch 19/1000] [Train_Loss: 0.759189 /Valid_Loss: 0.736934]
# [Epoch 19/1000] [Accuracy  : 0.648275]
# [Epoch 20/1000] [Train_Loss: 0.747997 /Valid_Loss: 0.732328]
# [Epoch 20/1000] [Accuracy  : 0.661112]
# [Epoch 21/1000] [Train_Loss: 0.728593 /Valid_Loss: 0.726641]
# [Epoch 21/1000] [Accuracy  : 0.650100]
# [Epoch 22/1000] [Train_Loss: 0.717033 /Valid_Loss: 0.711766]
# [Epoch 22/1000] [Accuracy  : 0.661975]
# [Epoch 23/1000] [Train_Loss: 0.720518 /Valid_Loss: 0.724924]
# [Epoch 23/1000] [Accuracy  : 0.655362]
# [Epoch 24/1000] [Train_Loss: 0.706313 /Valid_Loss: 0.704921]
# [Epoch 24/1000] [Accuracy  : 0.664200]
# [Epoch 25/1000] [Train_Loss: 0.710362 /Valid_Loss: 0.703206]
# [Epoch 25/1000] [Accuracy  : 0.665725]
# [Epoch 26/1000] [Train_Loss: 0.703672 /Valid_Loss: 0.703119]
# [Epoch 26/1000] [Accuracy  : 0.666325]
# [Epoch 27/1000] [Train_Loss: 0.707052 /Valid_Loss: 0.691428]
# [Epoch 27/1000] [Accuracy  : 0.671175]
# [Epoch 28/1000] [Train_Loss: 0.712362 /Valid_Loss: 0.694501]
# [Epoch 28/1000] [Accuracy  : 0.658075]
# [Epoch 29/1000] [Train_Loss: 0.695433 /Valid_Loss: 0.683611]
# [Epoch 29/1000] [Accuracy  : 0.677212]
# [Epoch 30/1000] [Train_Loss: 0.679077 /Valid_Loss: 0.686141]
# [Epoch 30/1000] [Accuracy  : 0.671925]
# [Epoch 31/1000] [Train_Loss: 0.688769 /Valid_Loss: 0.681383]
# [Epoch 31/1000] [Accuracy  : 0.671600]
# [Epoch 32/1000] [Train_Loss: 0.687243 /Valid_Loss: 0.677696]
# [Epoch 32/1000] [Accuracy  : 0.676075]
# [Epoch 33/1000] [Train_Loss: 0.688585 /Valid_Loss: 0.675597]
# [Epoch 33/1000] [Accuracy  : 0.678450]
# [Epoch 34/1000] [Train_Loss: 0.684929 /Valid_Loss: 0.671130]
# [Epoch 34/1000] [Accuracy  : 0.682262]
# [Epoch 35/1000] [Train_Loss: 0.668135 /Valid_Loss: 0.667915]
# [Epoch 35/1000] [Accuracy  : 0.679388]
# [Epoch 36/1000] [Train_Loss: 0.666086 /Valid_Loss: 0.670229]
# [Epoch 36/1000] [Accuracy  : 0.679312]
# [Epoch 37/1000] [Train_Loss: 0.674117 /Valid_Loss: 0.665167]
# [Epoch 37/1000] [Accuracy  : 0.686550]
# [Epoch 38/1000] [Train_Loss: 0.666380 /Valid_Loss: 0.664053]
# [Epoch 38/1000] [Accuracy  : 0.681575]
# [Epoch 39/1000] [Train_Loss: 0.682976 /Valid_Loss: 0.668827]
# [Epoch 39/1000] [Accuracy  : 0.686775]
# [Epoch 40/1000] [Train_Loss: 0.662298 /Valid_Loss: 0.660675]
# [Epoch 40/1000] [Accuracy  : 0.687262]
# [Epoch 41/1000] [Train_Loss: 0.660856 /Valid_Loss: 0.658851]
# [Epoch 41/1000] [Accuracy  : 0.685412]
# [Epoch 42/1000] [Train_Loss: 0.669632 /Valid_Loss: 0.657761]
# [Epoch 42/1000] [Accuracy  : 0.691237]
# [Epoch 43/1000] [Train_Loss: 0.658473 /Valid_Loss: 0.655074]
# [Epoch 43/1000] [Accuracy  : 0.694462]
# [Epoch 44/1000] [Train_Loss: 0.670375 /Valid_Loss: 0.661295]
# [Epoch 44/1000] [Accuracy  : 0.688400]
# [Epoch 45/1000] [Train_Loss: 0.646289 /Valid_Loss: 0.659097]
# [Epoch 45/1000] [Accuracy  : 0.696175]
# [Epoch 46/1000] [Train_Loss: 0.656892 /Valid_Loss: 0.655684]
# [Epoch 46/1000] [Accuracy  : 0.695263]
# [Epoch 47/1000] [Train_Loss: 0.656360 /Valid_Loss: 0.653868]
# [Epoch 47/1000] [Accuracy  : 0.695237]
# [Epoch 48/1000] [Train_Loss: 0.664646 /Valid_Loss: 0.650932]
# [Epoch 48/1000] [Accuracy  : 0.695500]
# [Epoch 49/1000] [Train_Loss: 0.651173 /Valid_Loss: 0.655310]
# [Epoch 49/1000] [Accuracy  : 0.692837]
# [Epoch 50/1000] [Train_Loss: 0.651215 /Valid_Loss: 0.651314]
# [Epoch 50/1000] [Accuracy  : 0.703400]
# [Epoch 51/1000] [Train_Loss: 0.654387 /Valid_Loss: 0.646453]
# [Epoch 51/1000] [Accuracy  : 0.706612]
# [Epoch 52/1000] [Train_Loss: 0.648452 /Valid_Loss: 0.644409]
# [Epoch 52/1000] [Accuracy  : 0.705488]
# [Epoch 53/1000] [Train_Loss: 0.655336 /Valid_Loss: 0.647168]
# [Epoch 53/1000] [Accuracy  : 0.707000]
# [Epoch 54/1000] [Train_Loss: 0.644852 /Valid_Loss: 0.645676]
# [Epoch 54/1000] [Accuracy  : 0.702337]
# [Epoch 55/1000] [Train_Loss: 0.652705 /Valid_Loss: 0.643012]
# [Epoch 55/1000] [Accuracy  : 0.710738]
# [Epoch 56/1000] [Train_Loss: 0.634624 /Valid_Loss: 0.651988]
# [Epoch 56/1000] [Accuracy  : 0.682338]
# [Epoch 57/1000] [Train_Loss: 0.649912 /Valid_Loss: 0.641097]
# [Epoch 57/1000] [Accuracy  : 0.700350]
# [Epoch 58/1000] [Train_Loss: 0.642243 /Valid_Loss: 0.644460]
# [Epoch 58/1000] [Accuracy  : 0.698963]
# [Epoch 59/1000] [Train_Loss: 0.636028 /Valid_Loss: 0.640840]
# [Epoch 59/1000] [Accuracy  : 0.709450]
# [Epoch 60/1000] [Train_Loss: 0.637867 /Valid_Loss: 0.640785]
# [Epoch 60/1000] [Accuracy  : 0.713475]
# [Epoch 61/1000] [Train_Loss: 0.652617 /Valid_Loss: 0.637290]
# [Epoch 61/1000] [Accuracy  : 0.713325]
# [Epoch 62/1000] [Train_Loss: 0.635839 /Valid_Loss: 0.634565]
# [Epoch 62/1000] [Accuracy  : 0.716925]
# [Epoch 63/1000] [Train_Loss: 0.643938 /Valid_Loss: 0.633758]
# [Epoch 63/1000] [Accuracy  : 0.715200]
# [Epoch 64/1000] [Train_Loss: 0.646226 /Valid_Loss: 0.634711]
# [Epoch 64/1000] [Accuracy  : 0.716725]
# [Epoch 65/1000] [Train_Loss: 0.634809 /Valid_Loss: 0.633329]
# [Epoch 65/1000] [Accuracy  : 0.710812]
# [Epoch 66/1000] [Train_Loss: 0.639048 /Valid_Loss: 0.635103]
# [Epoch 66/1000] [Accuracy  : 0.709800]
# [Epoch 67/1000] [Train_Loss: 0.647217 /Valid_Loss: 0.631480]
# [Epoch 67/1000] [Accuracy  : 0.714175]
# [Epoch 68/1000] [Train_Loss: 0.629033 /Valid_Loss: 0.631312]
# [Epoch 68/1000] [Accuracy  : 0.710237]
# [Epoch 69/1000] [Train_Loss: 0.635057 /Valid_Loss: 0.628767]
# [Epoch 69/1000] [Accuracy  : 0.710187]
# [Epoch 70/1000] [Train_Loss: 0.648792 /Valid_Loss: 0.628513]
# [Epoch 70/1000] [Accuracy  : 0.719213]
# [Epoch 71/1000] [Train_Loss: 0.627390 /Valid_Loss: 0.625628]
# [Epoch 71/1000] [Accuracy  : 0.714450]
# [Epoch 72/1000] [Train_Loss: 0.632557 /Valid_Loss: 0.624011]
# [Epoch 72/1000] [Accuracy  : 0.723487]
# [Epoch 73/1000] [Train_Loss: 0.620702 /Valid_Loss: 0.622889]
# [Epoch 73/1000] [Accuracy  : 0.722988]
# [Epoch 74/1000] [Train_Loss: 0.634016 /Valid_Loss: 0.626962]
# [Epoch 74/1000] [Accuracy  : 0.718337]
# [Epoch 75/1000] [Train_Loss: 0.630439 /Valid_Loss: 0.622274]
# [Epoch 75/1000] [Accuracy  : 0.716788]
# [Epoch 76/1000] [Train_Loss: 0.615371 /Valid_Loss: 0.623320]
# [Epoch 76/1000] [Accuracy  : 0.719050]
# [Epoch 77/1000] [Train_Loss: 0.610666 /Valid_Loss: 0.624713]
# [Epoch 77/1000] [Accuracy  : 0.716387]
# [Epoch 78/1000] [Train_Loss: 0.618076 /Valid_Loss: 0.618982]
# [Epoch 78/1000] [Accuracy  : 0.722237]
# [Epoch 79/1000] [Train_Loss: 0.624671 /Valid_Loss: 0.625138]
# [Epoch 79/1000] [Accuracy  : 0.714475]
# [Epoch 80/1000] [Train_Loss: 0.618782 /Valid_Loss: 0.614354]
# [Epoch 80/1000] [Accuracy  : 0.724325]
# [Epoch 81/1000] [Train_Loss: 0.628161 /Valid_Loss: 0.621676]
# [Epoch 81/1000] [Accuracy  : 0.720675]
# [Epoch 82/1000] [Train_Loss: 0.616562 /Valid_Loss: 0.617841]
# [Epoch 82/1000] [Accuracy  : 0.723187]
# [Epoch 83/1000] [Train_Loss: 0.625781 /Valid_Loss: 0.615886]
# [Epoch 83/1000] [Accuracy  : 0.721988]
# [Epoch 84/1000] [Train_Loss: 0.625008 /Valid_Loss: 0.616172]
# [Epoch 84/1000] [Accuracy  : 0.722400]
# [Epoch 85/1000] [Train_Loss: 0.612260 /Valid_Loss: 0.611532]
# [Epoch 85/1000] [Accuracy  : 0.723662]
# [Epoch 86/1000] [Train_Loss: 0.597126 /Valid_Loss: 0.615935]
# [Epoch 86/1000] [Accuracy  : 0.719925]
# [Epoch 87/1000] [Train_Loss: 0.619359 /Valid_Loss: 0.609882]
# [Epoch 87/1000] [Accuracy  : 0.723075]
# [Epoch 88/1000] [Train_Loss: 0.620109 /Valid_Loss: 0.612761]
# [Epoch 88/1000] [Accuracy  : 0.723400]
# [Epoch 89/1000] [Train_Loss: 0.620094 /Valid_Loss: 0.611060]
# [Epoch 89/1000] [Accuracy  : 0.725113]
# [Epoch 90/1000] [Train_Loss: 0.617330 /Valid_Loss: 0.607074]
# [Epoch 90/1000] [Accuracy  : 0.727325]
# [Epoch 91/1000] [Train_Loss: 0.603995 /Valid_Loss: 0.609186]
# [Epoch 91/1000] [Accuracy  : 0.726400]
# [Epoch 92/1000] [Train_Loss: 0.626437 /Valid_Loss: 0.616970]
# [Epoch 92/1000] [Accuracy  : 0.720575]
# [Epoch 93/1000] [Train_Loss: 0.598938 /Valid_Loss: 0.603778]
# [Epoch 93/1000] [Accuracy  : 0.729275]
# [Epoch 94/1000] [Train_Loss: 0.592795 /Valid_Loss: 0.606133]
# [Epoch 94/1000] [Accuracy  : 0.726163]
# [Epoch 95/1000] [Train_Loss: 0.606634 /Valid_Loss: 0.606079]
# [Epoch 95/1000] [Accuracy  : 0.726363]
# [Epoch 96/1000] [Train_Loss: 0.608211 /Valid_Loss: 0.605335]
# [Epoch 96/1000] [Accuracy  : 0.728600]
# [Epoch 97/1000] [Train_Loss: 0.624088 /Valid_Loss: 0.603314]
# [Epoch 97/1000] [Accuracy  : 0.729363]
# [Epoch 98/1000] [Train_Loss: 0.618381 /Valid_Loss: 0.604912]
# [Epoch 98/1000] [Accuracy  : 0.727812]
# [Epoch 99/1000] [Train_Loss: 0.603207 /Valid_Loss: 0.600402]
# [Epoch 99/1000] [Accuracy  : 0.728413]
# [Epoch 100/1000] [Train_Loss: 0.606913 /Valid_Loss: 0.601607]
# [Epoch 100/1000] [Accuracy  : 0.728575]
# [Epoch 101/1000] [Train_Loss: 0.577386 /Valid_Loss: 0.603338]
# [Epoch 101/1000] [Accuracy  : 0.727675]
# [Epoch 102/1000] [Train_Loss: 0.598973 /Valid_Loss: 0.601270]
# [Epoch 102/1000] [Accuracy  : 0.727850]
# [Epoch 103/1000] [Train_Loss: 0.601548 /Valid_Loss: 0.602891]
# [Epoch 103/1000] [Accuracy  : 0.727912]
# [Epoch 104/1000] [Train_Loss: 0.601180 /Valid_Loss: 0.600148]
# [Epoch 104/1000] [Accuracy  : 0.728975]
# [Epoch 105/1000] [Train_Loss: 0.604556 /Valid_Loss: 0.600613]
# [Epoch 105/1000] [Accuracy  : 0.728038]
# [Epoch 106/1000] [Train_Loss: 0.599769 /Valid_Loss: 0.601023]
# [Epoch 106/1000] [Accuracy  : 0.728662]
# [Epoch 107/1000] [Train_Loss: 0.600669 /Valid_Loss: 0.598600]
# [Epoch 107/1000] [Accuracy  : 0.727387]
# [Epoch 108/1000] [Train_Loss: 0.604739 /Valid_Loss: 0.601989]
# [Epoch 108/1000] [Accuracy  : 0.726163]
# [Epoch 109/1000] [Train_Loss: 0.583100 /Valid_Loss: 0.599764]
# [Epoch 109/1000] [Accuracy  : 0.730313]
# [Epoch 110/1000] [Train_Loss: 0.600227 /Valid_Loss: 0.603707]
# [Epoch 110/1000] [Accuracy  : 0.724237]
# [Epoch 111/1000] [Train_Loss: 0.597953 /Valid_Loss: 0.600874]
# [Epoch 111/1000] [Accuracy  : 0.725838]
# [Epoch 112/1000] [Train_Loss: 0.612101 /Valid_Loss: 0.600815]
# [Epoch 112/1000] [Accuracy  : 0.726187]
# [Epoch 113/1000] [Train_Loss: 0.601231 /Valid_Loss: 0.598817]
# [Epoch 113/1000] [Accuracy  : 0.729812]
# [Epoch 114/1000] [Train_Loss: 0.601115 /Valid_Loss: 0.601807]
# [Epoch 114/1000] [Accuracy  : 0.727075]
# [Epoch 115/1000] [Train_Loss: 0.591259 /Valid_Loss: 0.602111]
# [Epoch 115/1000] [Accuracy  : 0.730500]
# [Epoch 116/1000] [Train_Loss: 0.594968 /Valid_Loss: 0.597524]
# [Epoch 116/1000] [Accuracy  : 0.730650]
# [Epoch 117/1000] [Train_Loss: 0.596793 /Valid_Loss: 0.597668]
# [Epoch 117/1000] [Accuracy  : 0.730225]
# [Epoch 118/1000] [Train_Loss: 0.600787 /Valid_Loss: 0.596114]
# [Epoch 118/1000] [Accuracy  : 0.729563]
# [Epoch 119/1000] [Train_Loss: 0.595662 /Valid_Loss: 0.604935]
# [Epoch 119/1000] [Accuracy  : 0.726012]
# [Epoch 120/1000] [Train_Loss: 0.595220 /Valid_Loss: 0.598949]
# [Epoch 120/1000] [Accuracy  : 0.725962]
# [Epoch 121/1000] [Train_Loss: 0.586765 /Valid_Loss: 0.597727]
# [Epoch 121/1000] [Accuracy  : 0.727537]
# [Epoch 122/1000] [Train_Loss: 0.595013 /Valid_Loss: 0.605931]
# [Epoch 122/1000] [Accuracy  : 0.718325]
# [Epoch 123/1000] [Train_Loss: 0.606542 /Valid_Loss: 0.600590]
# [Epoch 123/1000] [Accuracy  : 0.729975]
# [Epoch 124/1000] [Train_Loss: 0.603486 /Valid_Loss: 0.599213]
# [Epoch 124/1000] [Accuracy  : 0.728838]
# [Epoch 125/1000] [Train_Loss: 0.588149 /Valid_Loss: 0.597351]
# [Epoch 125/1000] [Accuracy  : 0.729075]
# [Epoch 126/1000] [Train_Loss: 0.589751 /Valid_Loss: 0.597448]
# [Epoch 126/1000] [Accuracy  : 0.730012]
# [Epoch 127/1000] [Train_Loss: 0.594065 /Valid_Loss: 0.598019]
# [Epoch 127/1000] [Accuracy  : 0.728962]
# [Epoch 128/1000] [Train_Loss: 0.604517 /Valid_Loss: 0.599488]
# [Epoch 128/1000] [Accuracy  : 0.724925]
# [Epoch 129/1000] [Train_Loss: 0.607199 /Valid_Loss: 0.599452]
# [Epoch 129/1000] [Accuracy  : 0.724938]
# [Epoch 130/1000] [Train_Loss: 0.597979 /Valid_Loss: 0.594833]
# [Epoch 130/1000] [Accuracy  : 0.731012]
# [Epoch 131/1000] [Train_Loss: 0.593843 /Valid_Loss: 0.595380]
# [Epoch 131/1000] [Accuracy  : 0.730425]
# [Epoch 132/1000] [Train_Loss: 0.578794 /Valid_Loss: 0.596280]
# [Epoch 132/1000] [Accuracy  : 0.730738]
# [Epoch 133/1000] [Train_Loss: 0.600061 /Valid_Loss: 0.597334]
# [Epoch 133/1000] [Accuracy  : 0.725000]
# [Epoch 134/1000] [Train_Loss: 0.583687 /Valid_Loss: 0.594837]
# [Epoch 134/1000] [Accuracy  : 0.729213]
# [Epoch 135/1000] [Train_Loss: 0.586059 /Valid_Loss: 0.593541]
# [Epoch 135/1000] [Accuracy  : 0.732575]
# [Epoch 136/1000] [Train_Loss: 0.596257 /Valid_Loss: 0.594876]
# [Epoch 136/1000] [Accuracy  : 0.731550]
# [Epoch 137/1000] [Train_Loss: 0.593145 /Valid_Loss: 0.594398]
# [Epoch 137/1000] [Accuracy  : 0.729838]
# [Epoch 138/1000] [Train_Loss: 0.584026 /Valid_Loss: 0.596015]
# [Epoch 138/1000] [Accuracy  : 0.728850]
# [Epoch 139/1000] [Train_Loss: 0.603683 /Valid_Loss: 0.596430]
# [Epoch 139/1000] [Accuracy  : 0.724950]
# [Epoch 140/1000] [Train_Loss: 0.592059 /Valid_Loss: 0.610004]
# [Epoch 140/1000] [Accuracy  : 0.723213]
# [Epoch 141/1000] [Train_Loss: 0.592790 /Valid_Loss: 0.619911]
# [Epoch 141/1000] [Accuracy  : 0.718975]
# [Epoch 142/1000] [Train_Loss: 0.578255 /Valid_Loss: 0.597324]
# [Epoch 142/1000] [Accuracy  : 0.725912]
# [Epoch 143/1000] [Train_Loss: 0.579647 /Valid_Loss: 0.593185]
# [Epoch 143/1000] [Accuracy  : 0.728725]
# [Epoch 144/1000] [Train_Loss: 0.600912 /Valid_Loss: 0.596059]
# [Epoch 144/1000] [Accuracy  : 0.729750]
# [Epoch 145/1000] [Train_Loss: 0.597570 /Valid_Loss: 0.594593]
# [Epoch 145/1000] [Accuracy  : 0.727263]
# [Epoch 146/1000] [Train_Loss: 0.581419 /Valid_Loss: 0.593253]
# [Epoch 146/1000] [Accuracy  : 0.731625]
# [Epoch 147/1000] [Train_Loss: 0.593495 /Valid_Loss: 0.594627]
# [Epoch 147/1000] [Accuracy  : 0.728225]
# [Epoch 148/1000] [Train_Loss: 0.587347 /Valid_Loss: 0.597647]
# [Epoch 148/1000] [Accuracy  : 0.723087]
# [Epoch 149/1000] [Train_Loss: 0.609014 /Valid_Loss: 0.592085]
# [Epoch 149/1000] [Accuracy  : 0.730463]
# [Epoch 150/1000] [Train_Loss: 0.594335 /Valid_Loss: 0.593045]
# [Epoch 150/1000] [Accuracy  : 0.727075]
# [Epoch 151/1000] [Train_Loss: 0.595578 /Valid_Loss: 0.591243]
# [Epoch 151/1000] [Accuracy  : 0.732925]
# [Epoch 152/1000] [Train_Loss: 0.584567 /Valid_Loss: 0.595564]
# [Epoch 152/1000] [Accuracy  : 0.727113]
# [Epoch 153/1000] [Train_Loss: 0.603717 /Valid_Loss: 0.591561]
# [Epoch 153/1000] [Accuracy  : 0.730125]
# [Epoch 154/1000] [Train_Loss: 0.582589 /Valid_Loss: 0.589551]
# [Epoch 154/1000] [Accuracy  : 0.731563]
# [Epoch 155/1000] [Train_Loss: 0.602578 /Valid_Loss: 0.594250]
# [Epoch 155/1000] [Accuracy  : 0.731875]
# [Epoch 156/1000] [Train_Loss: 0.583405 /Valid_Loss: 0.593381]
# [Epoch 156/1000] [Accuracy  : 0.732100]
# [Epoch 157/1000] [Train_Loss: 0.575364 /Valid_Loss: 0.592878]
# [Epoch 157/1000] [Accuracy  : 0.730062]
# [Epoch 158/1000] [Train_Loss: 0.588762 /Valid_Loss: 0.591336]
# [Epoch 158/1000] [Accuracy  : 0.731575]
# [Epoch 159/1000] [Train_Loss: 0.574528 /Valid_Loss: 0.589862]
# [Epoch 159/1000] [Accuracy  : 0.733250]
# [Epoch 160/1000] [Train_Loss: 0.595866 /Valid_Loss: 0.592908]
# [Epoch 160/1000] [Accuracy  : 0.730337]
# [Epoch 161/1000] [Train_Loss: 0.586252 /Valid_Loss: 0.587941]
# [Epoch 161/1000] [Accuracy  : 0.732688]
# [Epoch 162/1000] [Train_Loss: 0.597333 /Valid_Loss: 0.587901]
# [Epoch 162/1000] [Accuracy  : 0.733287]
# [Epoch 163/1000] [Train_Loss: 0.603301 /Valid_Loss: 0.591165]
# [Epoch 163/1000] [Accuracy  : 0.731612]
# [Epoch 164/1000] [Train_Loss: 0.590728 /Valid_Loss: 0.588835]
# [Epoch 164/1000] [Accuracy  : 0.732850]
# [Epoch 165/1000] [Train_Loss: 0.591032 /Valid_Loss: 0.588359]
# [Epoch 165/1000] [Accuracy  : 0.732250]
# [Epoch 166/1000] [Train_Loss: 0.587495 /Valid_Loss: 0.590399]
# [Epoch 166/1000] [Accuracy  : 0.730850]
# [Epoch 167/1000] [Train_Loss: 0.596418 /Valid_Loss: 0.590465]
# [Epoch 167/1000] [Accuracy  : 0.732575]
# [Epoch 168/1000] [Train_Loss: 0.595807 /Valid_Loss: 0.588135]
# [Epoch 168/1000] [Accuracy  : 0.733137]
# [Epoch 169/1000] [Train_Loss: 0.598022 /Valid_Loss: 0.597711]
# [Epoch 169/1000] [Accuracy  : 0.726912]
# [Epoch 170/1000] [Train_Loss: 0.594334 /Valid_Loss: 0.588634]
# [Epoch 170/1000] [Accuracy  : 0.734175]
# [Epoch 171/1000] [Train_Loss: 0.576938 /Valid_Loss: 0.589164]
# [Epoch 171/1000] [Accuracy  : 0.731350]
# [Epoch 172/1000] [Train_Loss: 0.589759 /Valid_Loss: 0.594898]
# [Epoch 172/1000] [Accuracy  : 0.728287]
# [Epoch 173/1000] [Train_Loss: 0.593835 /Valid_Loss: 0.589564]
# [Epoch 173/1000] [Accuracy  : 0.731925]
# [Epoch 174/1000] [Train_Loss: 0.575811 /Valid_Loss: 0.586562]
# [Epoch 174/1000] [Accuracy  : 0.735375]
# [Epoch 175/1000] [Train_Loss: 0.591508 /Valid_Loss: 0.586618]
# [Epoch 175/1000] [Accuracy  : 0.733550]
# [Epoch 176/1000] [Train_Loss: 0.592970 /Valid_Loss: 0.588944]
# [Epoch 176/1000] [Accuracy  : 0.733662]
# [Epoch 177/1000] [Train_Loss: 0.589770 /Valid_Loss: 0.588415]
# [Epoch 177/1000] [Accuracy  : 0.731025]
# [Epoch 178/1000] [Train_Loss: 0.596950 /Valid_Loss: 0.588277]
# [Epoch 178/1000] [Accuracy  : 0.732625]
# [Epoch 179/1000] [Train_Loss: 0.607477 /Valid_Loss: 0.592414]
# [Epoch 179/1000] [Accuracy  : 0.726063]
# [Epoch 180/1000] [Train_Loss: 0.597824 /Valid_Loss: 0.588786]
# [Epoch 180/1000] [Accuracy  : 0.732050]
# [Epoch 181/1000] [Train_Loss: 0.596140 /Valid_Loss: 0.588682]
# [Epoch 181/1000] [Accuracy  : 0.730250]
# [Epoch 182/1000] [Train_Loss: 0.580991 /Valid_Loss: 0.588642]
# [Epoch 182/1000] [Accuracy  : 0.731612]
# [Epoch 183/1000] [Train_Loss: 0.578435 /Valid_Loss: 0.586250]
# [Epoch 183/1000] [Accuracy  : 0.734237]
# [Epoch 184/1000] [Train_Loss: 0.571549 /Valid_Loss: 0.585213]
# [Epoch 184/1000] [Accuracy  : 0.735337]
# [Epoch 185/1000] [Train_Loss: 0.583823 /Valid_Loss: 0.589899]
# [Epoch 185/1000] [Accuracy  : 0.731563]
# [Epoch 186/1000] [Train_Loss: 0.572104 /Valid_Loss: 0.592075]
# [Epoch 186/1000] [Accuracy  : 0.732038]
# [Epoch 187/1000] [Train_Loss: 0.591711 /Valid_Loss: 0.586694]
# [Epoch 187/1000] [Accuracy  : 0.734038]
# [Epoch 188/1000] [Train_Loss: 0.600459 /Valid_Loss: 0.588974]
# [Epoch 188/1000] [Accuracy  : 0.733988]
# [Epoch 189/1000] [Train_Loss: 0.596155 /Valid_Loss: 0.588586]
# [Epoch 189/1000] [Accuracy  : 0.733750]
# [Epoch 190/1000] [Train_Loss: 0.577519 /Valid_Loss: 0.587662]
# [Epoch 190/1000] [Accuracy  : 0.730525]
# [Epoch 191/1000] [Train_Loss: 0.576287 /Valid_Loss: 0.586061]
# [Epoch 191/1000] [Accuracy  : 0.732487]
# [Epoch 192/1000] [Train_Loss: 0.573010 /Valid_Loss: 0.587427]
# [Epoch 192/1000] [Accuracy  : 0.735487]
# [Epoch 193/1000] [Train_Loss: 0.602516 /Valid_Loss: 0.589387]
# [Epoch 193/1000] [Accuracy  : 0.730638]
# [Epoch 194/1000] [Train_Loss: 0.586219 /Valid_Loss: 0.583517]
# [Epoch 194/1000] [Accuracy  : 0.738062]
# [Epoch 195/1000] [Train_Loss: 0.594698 /Valid_Loss: 0.588286]
# [Epoch 195/1000] [Accuracy  : 0.730850]
# [Epoch 196/1000] [Train_Loss: 0.590038 /Valid_Loss: 0.587424]
# [Epoch 196/1000] [Accuracy  : 0.732350]
# [Epoch 197/1000] [Train_Loss: 0.597434 /Valid_Loss: 0.584185]
# [Epoch 197/1000] [Accuracy  : 0.736200]
# [Epoch 198/1000] [Train_Loss: 0.597859 /Valid_Loss: 0.586535]
# [Epoch 198/1000] [Accuracy  : 0.732137]
# [Epoch 199/1000] [Train_Loss: 0.601439 /Valid_Loss: 0.585678]
# [Epoch 199/1000] [Accuracy  : 0.733725]
# [Epoch 200/1000] [Train_Loss: 0.570607 /Valid_Loss: 0.585074]
# [Epoch 200/1000] [Accuracy  : 0.735000]
# [Epoch 201/1000] [Train_Loss: 0.590353 /Valid_Loss: 0.587940]
# [Epoch 201/1000] [Accuracy  : 0.733938]
# [Epoch 202/1000] [Train_Loss: 0.590693 /Valid_Loss: 0.586306]
# [Epoch 202/1000] [Accuracy  : 0.732812]
# [Epoch 203/1000] [Train_Loss: 0.600126 /Valid_Loss: 0.586464]
# [Epoch 203/1000] [Accuracy  : 0.732875]
# [Epoch 204/1000] [Train_Loss: 0.590958 /Valid_Loss: 0.587903]
# [Epoch 204/1000] [Accuracy  : 0.730825]
# [Epoch 205/1000] [Train_Loss: 0.590246 /Valid_Loss: 0.587641]
# [Epoch 205/1000] [Accuracy  : 0.734487]
# [Epoch 206/1000] [Train_Loss: 0.577258 /Valid_Loss: 0.585561]
# [Epoch 206/1000] [Accuracy  : 0.732775]
# [Epoch 207/1000] [Train_Loss: 0.593968 /Valid_Loss: 0.590527]
# [Epoch 207/1000] [Accuracy  : 0.730700]
# [Epoch 208/1000] [Train_Loss: 0.581870 /Valid_Loss: 0.589041]
# [Epoch 208/1000] [Accuracy  : 0.730700]
# [Epoch 209/1000] [Train_Loss: 0.590662 /Valid_Loss: 0.592189]
# [Epoch 209/1000] [Accuracy  : 0.729875]
# [Epoch 210/1000] [Train_Loss: 0.588403 /Valid_Loss: 0.588361]
# [Epoch 210/1000] [Accuracy  : 0.733788]
# [Epoch 211/1000] [Train_Loss: 0.593286 /Valid_Loss: 0.588979]
# [Epoch 211/1000] [Accuracy  : 0.731587]
# [Epoch 212/1000] [Train_Loss: 0.590777 /Valid_Loss: 0.586915]
# [Epoch 212/1000] [Accuracy  : 0.731912]
# [Epoch 213/1000] [Train_Loss: 0.590441 /Valid_Loss: 0.585545]
# [Epoch 213/1000] [Accuracy  : 0.733725]
# [Epoch 214/1000] [Train_Loss: 0.593823 /Valid_Loss: 0.587232]
# [Epoch 214/1000] [Accuracy  : 0.731700]
# [Epoch 215/1000] [Train_Loss: 0.577303 /Valid_Loss: 0.586087]
# [Epoch 215/1000] [Accuracy  : 0.734163]
# [Epoch 216/1000] [Train_Loss: 0.580154 /Valid_Loss: 0.589254]
# [Epoch 216/1000] [Accuracy  : 0.733525]
# [Epoch 217/1000] [Train_Loss: 0.586024 /Valid_Loss: 0.593156]
# [Epoch 217/1000] [Accuracy  : 0.726413]
# [Epoch 218/1000] [Train_Loss: 0.592454 /Valid_Loss: 0.585326]
# [Epoch 218/1000] [Accuracy  : 0.735225]
# [Epoch 219/1000] [Train_Loss: 0.591403 /Valid_Loss: 0.584785]
# [Epoch 219/1000] [Accuracy  : 0.733938]
# [Epoch 220/1000] [Train_Loss: 0.594271 /Valid_Loss: 0.586594]
# [Epoch 220/1000] [Accuracy  : 0.733513]
# [Epoch 221/1000] [Train_Loss: 0.574056 /Valid_Loss: 0.586319]
# [Epoch 221/1000] [Accuracy  : 0.732500]
# [Epoch 222/1000] [Train_Loss: 0.601400 /Valid_Loss: 0.585658]
# [Epoch 222/1000] [Accuracy  : 0.735387]
# [Epoch 223/1000] [Train_Loss: 0.588298 /Valid_Loss: 0.586875]
# [Epoch 223/1000] [Accuracy  : 0.733563]
# [Epoch 224/1000] [Train_Loss: 0.577153 /Valid_Loss: 0.585681]
# [Epoch 224/1000] [Accuracy  : 0.733225]
# [Epoch 225/1000] [Train_Loss: 0.592083 /Valid_Loss: 0.586466]
# [Epoch 225/1000] [Accuracy  : 0.734000]
# [Epoch 226/1000] [Train_Loss: 0.583199 /Valid_Loss: 0.586049]
# [Epoch 226/1000] [Accuracy  : 0.734137]
# [Epoch 227/1000] [Train_Loss: 0.574842 /Valid_Loss: 0.588140]
# [Epoch 227/1000] [Accuracy  : 0.732088]
# [Epoch 228/1000] [Train_Loss: 0.580154 /Valid_Loss: 0.585185]
# [Epoch 228/1000] [Accuracy  : 0.733225]
# [Epoch 229/1000] [Train_Loss: 0.595699 /Valid_Loss: 0.583617]
# [Epoch 229/1000] [Accuracy  : 0.737925]
# [Epoch 230/1000] [Train_Loss: 0.588090 /Valid_Loss: 0.586509]
# [Epoch 230/1000] [Accuracy  : 0.734725]
# [Epoch 231/1000] [Train_Loss: 0.586798 /Valid_Loss: 0.587609]
# [Epoch 231/1000] [Accuracy  : 0.733350]
# [Epoch 232/1000] [Train_Loss: 0.577442 /Valid_Loss: 0.585253]
# [Epoch 232/1000] [Accuracy  : 0.733375]
# [Epoch 233/1000] [Train_Loss: 0.584272 /Valid_Loss: 0.584836]
# [Epoch 233/1000] [Accuracy  : 0.735625]
# [Epoch 234/1000] [Train_Loss: 0.590705 /Valid_Loss: 0.585336]
# [Epoch 234/1000] [Accuracy  : 0.733237]
# [Epoch 235/1000] [Train_Loss: 0.586997 /Valid_Loss: 0.584207]
# [Epoch 235/1000] [Accuracy  : 0.731437]
# [Epoch 236/1000] [Train_Loss: 0.585234 /Valid_Loss: 0.583903]
# [Epoch 236/1000] [Accuracy  : 0.735263]
# [Epoch 237/1000] [Train_Loss: 0.580655 /Valid_Loss: 0.584954]
# [Epoch 237/1000] [Accuracy  : 0.734187]
# [Epoch 238/1000] [Train_Loss: 0.568475 /Valid_Loss: 0.587799]
# [Epoch 238/1000] [Accuracy  : 0.732850]
# [Epoch 239/1000] [Train_Loss: 0.606928 /Valid_Loss: 0.585999]
# [Epoch 239/1000] [Accuracy  : 0.731800]
# [Epoch 240/1000] [Train_Loss: 0.580044 /Valid_Loss: 0.585073]
# [Epoch 240/1000] [Accuracy  : 0.735000]
# [Epoch 241/1000] [Train_Loss: 0.576649 /Valid_Loss: 0.586344]
# [Epoch 241/1000] [Accuracy  : 0.731925]
# [Epoch 242/1000] [Train_Loss: 0.600825 /Valid_Loss: 0.582892]
# [Epoch 242/1000] [Accuracy  : 0.736487]
# [Epoch 243/1000] [Train_Loss: 0.594509 /Valid_Loss: 0.585326]
# [Epoch 243/1000] [Accuracy  : 0.733550]
# [Epoch 244/1000] [Train_Loss: 0.584015 /Valid_Loss: 0.585735]
# [Epoch 244/1000] [Accuracy  : 0.735050]
# [Epoch 245/1000] [Train_Loss: 0.581211 /Valid_Loss: 0.585871]
# [Epoch 245/1000] [Accuracy  : 0.734200]
# This is time to do early stopping
# 모델 저장: /content/gdrive/My Drive/Colab Notebooks/ai_mfg/rotor/cnn_model.pt

# %% [markdown]
# #### (1) 모델 평가

# %%
PATH = dir+'cnn_'
test_model(CNN_model, PATH)
# Out:
# 0.7366875

# %% [markdown]
# #### (2) 혼동 행렬 (Confusion matrix)

# %%
draw_confusion_matrix(CNN_model, x_test, y_test, PATH)

# %% [markdown]
# #### (3) 손실(Loss) 그래프

# %%
plot_loss_graph(CNN_loss_values, CNN_loss_values_v)

# %% [markdown]
# ### 5-3. 순환신경망 (RNN) 모델  성능 평가

# %%
# pytorch version : 1.9.0 (버전에 따라 아래 코드가 실행되지 않을 수 있으니 requirement.txt의 버전대로 설치해주세요)

RNN_model = KAMP_RNN()
num_epochs = 1000
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(RNN_model.parameters())
PATH = dir+'rnn_'

RNN_loss_values, RNN_loss_values_v = train_model(RNN_model, criterion, optimizer, num_epochs, train_dataloader, PATH)
# Out:
# [Epoch 1/1000] [Train_Loss: 1.386339 /Valid_Loss: 1.386325]
# [Epoch 1/1000] [Accuracy  : 0.249913]
# [Epoch 2/1000] [Train_Loss: 1.386244 /Valid_Loss: 1.386138]
# [Epoch 2/1000] [Accuracy  : 0.315775]
# [Epoch 3/1000] [Train_Loss: 1.382907 /Valid_Loss: 1.382616]
# [Epoch 3/1000] [Accuracy  : 0.356475]
# [Epoch 4/1000] [Train_Loss: 1.170598 /Valid_Loss: 1.161956]
# [Epoch 4/1000] [Accuracy  : 0.424750]
# [Epoch 5/1000] [Train_Loss: 1.107701 /Valid_Loss: 1.088935]
# [Epoch 5/1000] [Accuracy  : 0.431200]
# [Epoch 6/1000] [Train_Loss: 1.099407 /Valid_Loss: 1.086595]
# [Epoch 6/1000] [Accuracy  : 0.432400]
# [Epoch 7/1000] [Train_Loss: 1.092728 /Valid_Loss: 1.084403]
# [Epoch 7/1000] [Accuracy  : 0.448625]
# [Epoch 8/1000] [Train_Loss: 1.084109 /Valid_Loss: 1.082385]
# [Epoch 8/1000] [Accuracy  : 0.445487]
# [Epoch 9/1000] [Train_Loss: 1.084009 /Valid_Loss: 1.081187]
# [Epoch 9/1000] [Accuracy  : 0.463400]
# [Epoch 10/1000] [Train_Loss: 1.097530 /Valid_Loss: 1.079519]
# [Epoch 10/1000] [Accuracy  : 0.444675]
# [Epoch 11/1000] [Train_Loss: 1.073815 /Valid_Loss: 1.077713]
# [Epoch 11/1000] [Accuracy  : 0.445813]
# [Epoch 12/1000] [Train_Loss: 1.088394 /Valid_Loss: 1.075686]
# [Epoch 12/1000] [Accuracy  : 0.470112]
# [Epoch 13/1000] [Train_Loss: 1.068139 /Valid_Loss: 1.071586]
# [Epoch 13/1000] [Accuracy  : 0.466050]
# [Epoch 14/1000] [Train_Loss: 1.080178 /Valid_Loss: 1.066857]
# [Epoch 14/1000] [Accuracy  : 0.462388]
# [Epoch 15/1000] [Train_Loss: 1.072155 /Valid_Loss: 1.057733]
# [Epoch 15/1000] [Accuracy  : 0.475775]
# [Epoch 16/1000] [Train_Loss: 1.058223 /Valid_Loss: 1.039597]
# [Epoch 16/1000] [Accuracy  : 0.474625]
# [Epoch 17/1000] [Train_Loss: 1.003363 /Valid_Loss: 0.990200]
# [Epoch 17/1000] [Accuracy  : 0.485212]
# [Epoch 18/1000] [Train_Loss: 0.893661 /Valid_Loss: 0.874381]
# [Epoch 18/1000] [Accuracy  : 0.527288]
# [Epoch 19/1000] [Train_Loss: 0.860459 /Valid_Loss: 0.843431]
# [Epoch 19/1000] [Accuracy  : 0.529062]
# [Epoch 20/1000] [Train_Loss: 0.856376 /Valid_Loss: 0.837030]
# [Epoch 20/1000] [Accuracy  : 0.544538]
# [Epoch 21/1000] [Train_Loss: 0.858911 /Valid_Loss: 0.831501]
# [Epoch 21/1000] [Accuracy  : 0.537650]
# [Epoch 22/1000] [Train_Loss: 0.845490 /Valid_Loss: 0.827012]
# [Epoch 22/1000] [Accuracy  : 0.546100]
# [Epoch 23/1000] [Train_Loss: 0.849609 /Valid_Loss: 0.823778]
# [Epoch 23/1000] [Accuracy  : 0.543750]
# [Epoch 24/1000] [Train_Loss: 0.847953 /Valid_Loss: 0.819948]
# [Epoch 24/1000] [Accuracy  : 0.559213]
# [Epoch 25/1000] [Train_Loss: 0.843018 /Valid_Loss: 0.816046]
# [Epoch 25/1000] [Accuracy  : 0.553987]
# [Epoch 26/1000] [Train_Loss: 0.835315 /Valid_Loss: 0.813034]
# [Epoch 26/1000] [Accuracy  : 0.558025]
# [Epoch 27/1000] [Train_Loss: 0.837434 /Valid_Loss: 0.809238]
# [Epoch 27/1000] [Accuracy  : 0.563837]
# [Epoch 28/1000] [Train_Loss: 0.824163 /Valid_Loss: 0.805823]
# [Epoch 28/1000] [Accuracy  : 0.568113]
# [Epoch 29/1000] [Train_Loss: 0.821038 /Valid_Loss: 0.803941]
# [Epoch 29/1000] [Accuracy  : 0.569100]
# [Epoch 30/1000] [Train_Loss: 0.810406 /Valid_Loss: 0.801692]
# [Epoch 30/1000] [Accuracy  : 0.571525]
# [Epoch 31/1000] [Train_Loss: 0.836146 /Valid_Loss: 0.797052]
# [Epoch 31/1000] [Accuracy  : 0.569338]
# [Epoch 32/1000] [Train_Loss: 0.813090 /Valid_Loss: 0.795698]
# [Epoch 32/1000] [Accuracy  : 0.577063]
# [Epoch 33/1000] [Train_Loss: 0.813320 /Valid_Loss: 0.792770]
# [Epoch 33/1000] [Accuracy  : 0.583688]
# [Epoch 34/1000] [Train_Loss: 0.811009 /Valid_Loss: 0.791032]
# [Epoch 34/1000] [Accuracy  : 0.578225]
# [Epoch 35/1000] [Train_Loss: 0.829011 /Valid_Loss: 0.788058]
# [Epoch 35/1000] [Accuracy  : 0.585013]
# [Epoch 36/1000] [Train_Loss: 0.813660 /Valid_Loss: 0.785991]
# [Epoch 36/1000] [Accuracy  : 0.590013]
# [Epoch 37/1000] [Train_Loss: 0.801720 /Valid_Loss: 0.783536]
# [Epoch 37/1000] [Accuracy  : 0.593988]
# [Epoch 38/1000] [Train_Loss: 0.812273 /Valid_Loss: 0.781487]
# [Epoch 38/1000] [Accuracy  : 0.592700]
# [Epoch 39/1000] [Train_Loss: 0.805830 /Valid_Loss: 0.779258]
# [Epoch 39/1000] [Accuracy  : 0.594500]
# [Epoch 40/1000] [Train_Loss: 0.799098 /Valid_Loss: 0.778132]
# [Epoch 40/1000] [Accuracy  : 0.596950]
# [Epoch 41/1000] [Train_Loss: 0.784426 /Valid_Loss: 0.775570]
# [Epoch 41/1000] [Accuracy  : 0.602925]
# [Epoch 42/1000] [Train_Loss: 0.801987 /Valid_Loss: 0.774646]
# [Epoch 42/1000] [Accuracy  : 0.604487]
# [Epoch 43/1000] [Train_Loss: 0.804627 /Valid_Loss: 0.770430]
# [Epoch 43/1000] [Accuracy  : 0.603912]
# [Epoch 44/1000] [Train_Loss: 0.788015 /Valid_Loss: 0.767648]
# [Epoch 44/1000] [Accuracy  : 0.605137]
# [Epoch 45/1000] [Train_Loss: 0.799358 /Valid_Loss: 0.765554]
# [Epoch 45/1000] [Accuracy  : 0.612163]
# [Epoch 46/1000] [Train_Loss: 0.776299 /Valid_Loss: 0.769427]
# [Epoch 46/1000] [Accuracy  : 0.613587]
# [Epoch 47/1000] [Train_Loss: 0.787745 /Valid_Loss: 0.761846]
# [Epoch 47/1000] [Accuracy  : 0.619325]
# [Epoch 48/1000] [Train_Loss: 0.780116 /Valid_Loss: 0.762930]
# [Epoch 48/1000] [Accuracy  : 0.618762]
# [Epoch 49/1000] [Train_Loss: 0.788306 /Valid_Loss: 0.758616]
# [Epoch 49/1000] [Accuracy  : 0.621938]
# [Epoch 50/1000] [Train_Loss: 0.766307 /Valid_Loss: 0.760737]
# [Epoch 50/1000] [Accuracy  : 0.620850]
# [Epoch 51/1000] [Train_Loss: 0.763629 /Valid_Loss: 0.757747]
# [Epoch 51/1000] [Accuracy  : 0.615012]
# [Epoch 52/1000] [Train_Loss: 0.774940 /Valid_Loss: 0.755802]
# [Epoch 52/1000] [Accuracy  : 0.624325]
# [Epoch 53/1000] [Train_Loss: 0.762499 /Valid_Loss: 0.755570]
# [Epoch 53/1000] [Accuracy  : 0.625325]
# [Epoch 54/1000] [Train_Loss: 0.777877 /Valid_Loss: 0.754807]
# [Epoch 54/1000] [Accuracy  : 0.622938]
# [Epoch 55/1000] [Train_Loss: 0.766439 /Valid_Loss: 0.755490]
# [Epoch 55/1000] [Accuracy  : 0.623850]
# [Epoch 56/1000] [Train_Loss: 0.766732 /Valid_Loss: 0.755094]
# [Epoch 56/1000] [Accuracy  : 0.623250]
# [Epoch 57/1000] [Train_Loss: 0.761810 /Valid_Loss: 0.753629]
# [Epoch 57/1000] [Accuracy  : 0.623537]
# [Epoch 58/1000] [Train_Loss: 0.769329 /Valid_Loss: 0.753673]
# [Epoch 58/1000] [Accuracy  : 0.622850]
# [Epoch 59/1000] [Train_Loss: 0.759609 /Valid_Loss: 0.754540]
# [Epoch 59/1000] [Accuracy  : 0.622838]
# [Epoch 60/1000] [Train_Loss: 0.777333 /Valid_Loss: 0.754720]
# [Epoch 60/1000] [Accuracy  : 0.619550]
# [Epoch 61/1000] [Train_Loss: 0.787459 /Valid_Loss: 0.755306]
# [Epoch 61/1000] [Accuracy  : 0.623862]
# [Epoch 62/1000] [Train_Loss: 0.759959 /Valid_Loss: 0.749932]
# [Epoch 62/1000] [Accuracy  : 0.622800]
# [Epoch 63/1000] [Train_Loss: 0.759392 /Valid_Loss: 0.750924]
# [Epoch 63/1000] [Accuracy  : 0.619725]
# [Epoch 64/1000] [Train_Loss: 0.766472 /Valid_Loss: 0.750228]
# [Epoch 64/1000] [Accuracy  : 0.623637]
# [Epoch 65/1000] [Train_Loss: 0.772744 /Valid_Loss: 0.750464]
# [Epoch 65/1000] [Accuracy  : 0.623325]
# [Epoch 66/1000] [Train_Loss: 0.735759 /Valid_Loss: 0.748578]
# [Epoch 66/1000] [Accuracy  : 0.621613]
# [Epoch 67/1000] [Train_Loss: 0.750629 /Valid_Loss: 0.750025]
# [Epoch 67/1000] [Accuracy  : 0.622700]
# [Epoch 68/1000] [Train_Loss: 0.755916 /Valid_Loss: 0.749109]
# [Epoch 68/1000] [Accuracy  : 0.622112]
# [Epoch 69/1000] [Train_Loss: 0.763154 /Valid_Loss: 0.749542]
# [Epoch 69/1000] [Accuracy  : 0.623675]
# [Epoch 70/1000] [Train_Loss: 0.760566 /Valid_Loss: 0.747567]
# [Epoch 70/1000] [Accuracy  : 0.626500]
# [Epoch 71/1000] [Train_Loss: 0.741340 /Valid_Loss: 0.749312]
# [Epoch 71/1000] [Accuracy  : 0.619600]
# [Epoch 72/1000] [Train_Loss: 0.758655 /Valid_Loss: 0.746811]
# [Epoch 72/1000] [Accuracy  : 0.627287]
# [Epoch 73/1000] [Train_Loss: 0.754663 /Valid_Loss: 0.747343]
# [Epoch 73/1000] [Accuracy  : 0.623737]
# [Epoch 74/1000] [Train_Loss: 0.752362 /Valid_Loss: 0.747373]
# [Epoch 74/1000] [Accuracy  : 0.621500]
# [Epoch 75/1000] [Train_Loss: 0.755148 /Valid_Loss: 0.745853]
# [Epoch 75/1000] [Accuracy  : 0.625437]
# [Epoch 76/1000] [Train_Loss: 0.748424 /Valid_Loss: 0.745662]
# [Epoch 76/1000] [Accuracy  : 0.625962]
# [Epoch 77/1000] [Train_Loss: 0.741272 /Valid_Loss: 0.745313]
# [Epoch 77/1000] [Accuracy  : 0.622475]
# [Epoch 78/1000] [Train_Loss: 0.742119 /Valid_Loss: 0.745780]
# [Epoch 78/1000] [Accuracy  : 0.623463]
# [Epoch 79/1000] [Train_Loss: 0.753367 /Valid_Loss: 0.745905]
# [Epoch 79/1000] [Accuracy  : 0.620825]
# [Epoch 80/1000] [Train_Loss: 0.736185 /Valid_Loss: 0.746132]
# [Epoch 80/1000] [Accuracy  : 0.621375]
# [Epoch 81/1000] [Train_Loss: 0.745571 /Valid_Loss: 0.745149]
# [Epoch 81/1000] [Accuracy  : 0.626400]
# [Epoch 82/1000] [Train_Loss: 0.739371 /Valid_Loss: 0.743603]
# [Epoch 82/1000] [Accuracy  : 0.621200]
# [Epoch 83/1000] [Train_Loss: 0.748687 /Valid_Loss: 0.746100]
# [Epoch 83/1000] [Accuracy  : 0.625162]
# [Epoch 84/1000] [Train_Loss: 0.751970 /Valid_Loss: 0.743678]
# [Epoch 84/1000] [Accuracy  : 0.620225]
# [Epoch 85/1000] [Train_Loss: 0.754431 /Valid_Loss: 0.744141]
# [Epoch 85/1000] [Accuracy  : 0.628500]
# [Epoch 86/1000] [Train_Loss: 0.744165 /Valid_Loss: 0.742384]
# [Epoch 86/1000] [Accuracy  : 0.628300]
# [Epoch 87/1000] [Train_Loss: 0.756172 /Valid_Loss: 0.745944]
# [Epoch 87/1000] [Accuracy  : 0.619475]
# [Epoch 88/1000] [Train_Loss: 0.758384 /Valid_Loss: 0.741464]
# [Epoch 88/1000] [Accuracy  : 0.621025]
# [Epoch 89/1000] [Train_Loss: 0.750685 /Valid_Loss: 0.744657]
# [Epoch 89/1000] [Accuracy  : 0.620475]
# [Epoch 90/1000] [Train_Loss: 0.745611 /Valid_Loss: 0.745393]
# [Epoch 90/1000] [Accuracy  : 0.624425]
# [Epoch 91/1000] [Train_Loss: 0.753233 /Valid_Loss: 0.742197]
# [Epoch 91/1000] [Accuracy  : 0.621513]
# [Epoch 92/1000] [Train_Loss: 0.753493 /Valid_Loss: 0.740320]
# [Epoch 92/1000] [Accuracy  : 0.627138]
# [Epoch 93/1000] [Train_Loss: 0.742747 /Valid_Loss: 0.744190]
# [Epoch 93/1000] [Accuracy  : 0.624238]
# [Epoch 94/1000] [Train_Loss: 0.742921 /Valid_Loss: 0.742681]
# [Epoch 94/1000] [Accuracy  : 0.622237]
# [Epoch 95/1000] [Train_Loss: 0.741592 /Valid_Loss: 0.741723]
# [Epoch 95/1000] [Accuracy  : 0.622150]
# [Epoch 96/1000] [Train_Loss: 0.748203 /Valid_Loss: 0.739920]
# [Epoch 96/1000] [Accuracy  : 0.624025]
# [Epoch 97/1000] [Train_Loss: 0.749762 /Valid_Loss: 0.742406]
# [Epoch 97/1000] [Accuracy  : 0.625313]
# [Epoch 98/1000] [Train_Loss: 0.750606 /Valid_Loss: 0.741024]
# [Epoch 98/1000] [Accuracy  : 0.624313]
# [Epoch 99/1000] [Train_Loss: 0.739032 /Valid_Loss: 0.740773]
# [Epoch 99/1000] [Accuracy  : 0.624463]
# [Epoch 100/1000] [Train_Loss: 0.746972 /Valid_Loss: 0.742326]
# [Epoch 100/1000] [Accuracy  : 0.626025]
# [Epoch 101/1000] [Train_Loss: 0.730032 /Valid_Loss: 0.740469]
# [Epoch 101/1000] [Accuracy  : 0.627550]
# [Epoch 102/1000] [Train_Loss: 0.732816 /Valid_Loss: 0.738878]
# [Epoch 102/1000] [Accuracy  : 0.627575]
# [Epoch 103/1000] [Train_Loss: 0.733597 /Valid_Loss: 0.741015]
# [Epoch 103/1000] [Accuracy  : 0.624263]
# [Epoch 104/1000] [Train_Loss: 0.749567 /Valid_Loss: 0.740339]
# [Epoch 104/1000] [Accuracy  : 0.625475]
# [Epoch 105/1000] [Train_Loss: 0.744627 /Valid_Loss: 0.738467]
# [Epoch 105/1000] [Accuracy  : 0.630288]
# [Epoch 106/1000] [Train_Loss: 0.729594 /Valid_Loss: 0.735216]
# [Epoch 106/1000] [Accuracy  : 0.633175]
# [Epoch 107/1000] [Train_Loss: 0.730135 /Valid_Loss: 0.735382]
# [Epoch 107/1000] [Accuracy  : 0.630500]
# [Epoch 108/1000] [Train_Loss: 0.730049 /Valid_Loss: 0.729680]
# [Epoch 108/1000] [Accuracy  : 0.643162]
# [Epoch 109/1000] [Train_Loss: 0.727315 /Valid_Loss: 0.731307]
# [Epoch 109/1000] [Accuracy  : 0.643225]
# [Epoch 110/1000] [Train_Loss: 0.713321 /Valid_Loss: 0.725214]
# [Epoch 110/1000] [Accuracy  : 0.653550]
# [Epoch 111/1000] [Train_Loss: 0.717110 /Valid_Loss: 0.720247]
# [Epoch 111/1000] [Accuracy  : 0.659663]
# [Epoch 112/1000] [Train_Loss: 0.720942 /Valid_Loss: 0.713957]
# [Epoch 112/1000] [Accuracy  : 0.662188]
# [Epoch 113/1000] [Train_Loss: 0.711536 /Valid_Loss: 0.705227]
# [Epoch 113/1000] [Accuracy  : 0.670225]
# [Epoch 114/1000] [Train_Loss: 0.689399 /Valid_Loss: 0.697631]
# [Epoch 114/1000] [Accuracy  : 0.678963]
# [Epoch 115/1000] [Train_Loss: 0.679858 /Valid_Loss: 0.695549]
# [Epoch 115/1000] [Accuracy  : 0.683250]
# [Epoch 116/1000] [Train_Loss: 0.670837 /Valid_Loss: 0.685123]
# [Epoch 116/1000] [Accuracy  : 0.687925]
# [Epoch 117/1000] [Train_Loss: 0.658947 /Valid_Loss: 0.680012]
# [Epoch 117/1000] [Accuracy  : 0.688325]
# [Epoch 118/1000] [Train_Loss: 0.666870 /Valid_Loss: 0.673520]
# [Epoch 118/1000] [Accuracy  : 0.693738]
# [Epoch 119/1000] [Train_Loss: 0.662066 /Valid_Loss: 0.666265]
# [Epoch 119/1000] [Accuracy  : 0.698775]
# [Epoch 120/1000] [Train_Loss: 0.666980 /Valid_Loss: 0.660882]
# [Epoch 120/1000] [Accuracy  : 0.698887]
# [Epoch 121/1000] [Train_Loss: 0.652329 /Valid_Loss: 0.657581]
# [Epoch 121/1000] [Accuracy  : 0.701013]
# [Epoch 122/1000] [Train_Loss: 0.653141 /Valid_Loss: 0.656148]
# [Epoch 122/1000] [Accuracy  : 0.698237]
# [Epoch 123/1000] [Train_Loss: 0.648561 /Valid_Loss: 0.651371]
# [Epoch 123/1000] [Accuracy  : 0.701812]
# [Epoch 124/1000] [Train_Loss: 0.622223 /Valid_Loss: 0.651961]
# [Epoch 124/1000] [Accuracy  : 0.696812]
# [Epoch 125/1000] [Train_Loss: 0.659478 /Valid_Loss: 0.646053]
# [Epoch 125/1000] [Accuracy  : 0.704500]
# [Epoch 126/1000] [Train_Loss: 0.633058 /Valid_Loss: 0.652182]
# [Epoch 126/1000] [Accuracy  : 0.698275]
# [Epoch 127/1000] [Train_Loss: 0.602116 /Valid_Loss: 0.648348]
# [Epoch 127/1000] [Accuracy  : 0.701412]
# [Epoch 128/1000] [Train_Loss: 0.638637 /Valid_Loss: 0.646603]
# [Epoch 128/1000] [Accuracy  : 0.701987]
# [Epoch 129/1000] [Train_Loss: 0.611506 /Valid_Loss: 0.644064]
# [Epoch 129/1000] [Accuracy  : 0.706475]
# [Epoch 130/1000] [Train_Loss: 0.614645 /Valid_Loss: 0.645656]
# [Epoch 130/1000] [Accuracy  : 0.703675]
# [Epoch 131/1000] [Train_Loss: 0.614517 /Valid_Loss: 0.644108]
# [Epoch 131/1000] [Accuracy  : 0.705175]
# [Epoch 132/1000] [Train_Loss: 0.604323 /Valid_Loss: 0.642189]
# [Epoch 132/1000] [Accuracy  : 0.706838]
# [Epoch 133/1000] [Train_Loss: 0.629620 /Valid_Loss: 0.641723]
# [Epoch 133/1000] [Accuracy  : 0.708025]
# [Epoch 134/1000] [Train_Loss: 0.605381 /Valid_Loss: 0.638679]
# [Epoch 134/1000] [Accuracy  : 0.708825]
# [Epoch 135/1000] [Train_Loss: 0.607056 /Valid_Loss: 0.638518]
# [Epoch 135/1000] [Accuracy  : 0.707750]
# [Epoch 136/1000] [Train_Loss: 0.600174 /Valid_Loss: 0.636905]
# [Epoch 136/1000] [Accuracy  : 0.710187]
# [Epoch 137/1000] [Train_Loss: 0.611345 /Valid_Loss: 0.636863]
# [Epoch 137/1000] [Accuracy  : 0.708850]
# [Epoch 138/1000] [Train_Loss: 0.594216 /Valid_Loss: 0.637196]
# [Epoch 138/1000] [Accuracy  : 0.709963]
# [Epoch 139/1000] [Train_Loss: 0.594869 /Valid_Loss: 0.636526]
# [Epoch 139/1000] [Accuracy  : 0.710387]
# [Epoch 140/1000] [Train_Loss: 0.610430 /Valid_Loss: 0.636729]
# [Epoch 140/1000] [Accuracy  : 0.709300]
# [Epoch 141/1000] [Train_Loss: 0.595799 /Valid_Loss: 0.636282]
# [Epoch 141/1000] [Accuracy  : 0.708237]
# [Epoch 142/1000] [Train_Loss: 0.618771 /Valid_Loss: 0.631345]
# [Epoch 142/1000] [Accuracy  : 0.712675]
# [Epoch 143/1000] [Train_Loss: 0.601334 /Valid_Loss: 0.634166]
# [Epoch 143/1000] [Accuracy  : 0.712150]
# [Epoch 144/1000] [Train_Loss: 0.593605 /Valid_Loss: 0.633668]
# [Epoch 144/1000] [Accuracy  : 0.712375]
# [Epoch 145/1000] [Train_Loss: 0.605345 /Valid_Loss: 0.628849]
# [Epoch 145/1000] [Accuracy  : 0.713488]
# [Epoch 146/1000] [Train_Loss: 0.576969 /Valid_Loss: 0.629167]
# [Epoch 146/1000] [Accuracy  : 0.714900]
# [Epoch 147/1000] [Train_Loss: 0.584186 /Valid_Loss: 0.628195]
# [Epoch 147/1000] [Accuracy  : 0.716675]
# [Epoch 148/1000] [Train_Loss: 0.585681 /Valid_Loss: 0.625996]
# [Epoch 148/1000] [Accuracy  : 0.716688]
# [Epoch 149/1000] [Train_Loss: 0.606853 /Valid_Loss: 0.628998]
# [Epoch 149/1000] [Accuracy  : 0.715562]
# [Epoch 150/1000] [Train_Loss: 0.589958 /Valid_Loss: 0.622392]
# [Epoch 150/1000] [Accuracy  : 0.717950]
# [Epoch 151/1000] [Train_Loss: 0.599025 /Valid_Loss: 0.626178]
# [Epoch 151/1000] [Accuracy  : 0.716962]
# [Epoch 152/1000] [Train_Loss: 0.589171 /Valid_Loss: 0.624034]
# [Epoch 152/1000] [Accuracy  : 0.717375]
# [Epoch 153/1000] [Train_Loss: 0.576514 /Valid_Loss: 0.622723]
# [Epoch 153/1000] [Accuracy  : 0.718612]
# [Epoch 154/1000] [Train_Loss: 0.584655 /Valid_Loss: 0.624115]
# [Epoch 154/1000] [Accuracy  : 0.718300]
# [Epoch 155/1000] [Train_Loss: 0.594878 /Valid_Loss: 0.622387]
# [Epoch 155/1000] [Accuracy  : 0.720137]
# [Epoch 156/1000] [Train_Loss: 0.598983 /Valid_Loss: 0.622400]
# [Epoch 156/1000] [Accuracy  : 0.718163]
# [Epoch 157/1000] [Train_Loss: 0.589966 /Valid_Loss: 0.618274]
# [Epoch 157/1000] [Accuracy  : 0.720875]
# [Epoch 158/1000] [Train_Loss: 0.570659 /Valid_Loss: 0.618479]
# [Epoch 158/1000] [Accuracy  : 0.721225]
# [Epoch 159/1000] [Train_Loss: 0.587662 /Valid_Loss: 0.616298]
# [Epoch 159/1000] [Accuracy  : 0.723525]
# [Epoch 160/1000] [Train_Loss: 0.580833 /Valid_Loss: 0.615304]
# [Epoch 160/1000] [Accuracy  : 0.723888]
# [Epoch 161/1000] [Train_Loss: 0.564811 /Valid_Loss: 0.616046]
# [Epoch 161/1000] [Accuracy  : 0.721075]
# [Epoch 162/1000] [Train_Loss: 0.570853 /Valid_Loss: 0.618914]
# [Epoch 162/1000] [Accuracy  : 0.719812]
# [Epoch 163/1000] [Train_Loss: 0.557849 /Valid_Loss: 0.616266]
# [Epoch 163/1000] [Accuracy  : 0.720413]
# [Epoch 164/1000] [Train_Loss: 0.579663 /Valid_Loss: 0.614721]
# [Epoch 164/1000] [Accuracy  : 0.721638]
# [Epoch 165/1000] [Train_Loss: 0.574813 /Valid_Loss: 0.616436]
# [Epoch 165/1000] [Accuracy  : 0.721287]
# [Epoch 166/1000] [Train_Loss: 0.587702 /Valid_Loss: 0.614525]
# [Epoch 166/1000] [Accuracy  : 0.721762]
# [Epoch 167/1000] [Train_Loss: 0.571906 /Valid_Loss: 0.616624]
# [Epoch 167/1000] [Accuracy  : 0.721450]
# [Epoch 168/1000] [Train_Loss: 0.545061 /Valid_Loss: 0.614200]
# [Epoch 168/1000] [Accuracy  : 0.722562]
# [Epoch 169/1000] [Train_Loss: 0.566239 /Valid_Loss: 0.616707]
# [Epoch 169/1000] [Accuracy  : 0.723000]
# [Epoch 170/1000] [Train_Loss: 0.577897 /Valid_Loss: 0.614234]
# [Epoch 170/1000] [Accuracy  : 0.722988]
# [Epoch 171/1000] [Train_Loss: 0.573368 /Valid_Loss: 0.611870]
# [Epoch 171/1000] [Accuracy  : 0.724537]
# [Epoch 172/1000] [Train_Loss: 0.575666 /Valid_Loss: 0.611374]
# [Epoch 172/1000] [Accuracy  : 0.725325]
# [Epoch 173/1000] [Train_Loss: 0.571684 /Valid_Loss: 0.611229]
# [Epoch 173/1000] [Accuracy  : 0.724912]
# [Epoch 174/1000] [Train_Loss: 0.573099 /Valid_Loss: 0.608671]
# [Epoch 174/1000] [Accuracy  : 0.724575]
# [Epoch 175/1000] [Train_Loss: 0.579549 /Valid_Loss: 0.607082]
# [Epoch 175/1000] [Accuracy  : 0.727237]
# [Epoch 176/1000] [Train_Loss: 0.566927 /Valid_Loss: 0.608442]
# [Epoch 176/1000] [Accuracy  : 0.725163]
# [Epoch 177/1000] [Train_Loss: 0.575406 /Valid_Loss: 0.608716]
# [Epoch 177/1000] [Accuracy  : 0.725325]
# [Epoch 178/1000] [Train_Loss: 0.580218 /Valid_Loss: 0.608430]
# [Epoch 178/1000] [Accuracy  : 0.725850]
# [Epoch 179/1000] [Train_Loss: 0.565709 /Valid_Loss: 0.606200]
# [Epoch 179/1000] [Accuracy  : 0.727675]
# [Epoch 180/1000] [Train_Loss: 0.547150 /Valid_Loss: 0.611004]
# [Epoch 180/1000] [Accuracy  : 0.725463]
# [Epoch 181/1000] [Train_Loss: 0.567407 /Valid_Loss: 0.606645]
# [Epoch 181/1000] [Accuracy  : 0.731187]
# [Epoch 182/1000] [Train_Loss: 0.551977 /Valid_Loss: 0.606132]
# [Epoch 182/1000] [Accuracy  : 0.728350]
# [Epoch 183/1000] [Train_Loss: 0.575268 /Valid_Loss: 0.604845]
# [Epoch 183/1000] [Accuracy  : 0.727900]
# [Epoch 184/1000] [Train_Loss: 0.566603 /Valid_Loss: 0.604680]
# [Epoch 184/1000] [Accuracy  : 0.730750]
# [Epoch 185/1000] [Train_Loss: 0.569789 /Valid_Loss: 0.607982]
# [Epoch 185/1000] [Accuracy  : 0.730200]
# [Epoch 186/1000] [Train_Loss: 0.564512 /Valid_Loss: 0.604970]
# [Epoch 186/1000] [Accuracy  : 0.729662]
# [Epoch 187/1000] [Train_Loss: 0.548678 /Valid_Loss: 0.605043]
# [Epoch 187/1000] [Accuracy  : 0.730113]
# [Epoch 188/1000] [Train_Loss: 0.548908 /Valid_Loss: 0.601036]
# [Epoch 188/1000] [Accuracy  : 0.732075]
# [Epoch 189/1000] [Train_Loss: 0.568031 /Valid_Loss: 0.599637]
# [Epoch 189/1000] [Accuracy  : 0.733387]
# [Epoch 190/1000] [Train_Loss: 0.561094 /Valid_Loss: 0.607504]
# [Epoch 190/1000] [Accuracy  : 0.729200]
# [Epoch 191/1000] [Train_Loss: 0.559017 /Valid_Loss: 0.605213]
# [Epoch 191/1000] [Accuracy  : 0.728875]
# [Epoch 192/1000] [Train_Loss: 0.555760 /Valid_Loss: 0.602529]
# [Epoch 192/1000] [Accuracy  : 0.730363]
# [Epoch 193/1000] [Train_Loss: 0.569583 /Valid_Loss: 0.600233]
# [Epoch 193/1000] [Accuracy  : 0.732875]
# [Epoch 194/1000] [Train_Loss: 0.540404 /Valid_Loss: 0.602772]
# [Epoch 194/1000] [Accuracy  : 0.730600]
# [Epoch 195/1000] [Train_Loss: 0.543682 /Valid_Loss: 0.596815]
# [Epoch 195/1000] [Accuracy  : 0.736537]
# [Epoch 196/1000] [Train_Loss: 0.564099 /Valid_Loss: 0.599782]
# [Epoch 196/1000] [Accuracy  : 0.732250]
# [Epoch 197/1000] [Train_Loss: 0.550531 /Valid_Loss: 0.597996]
# [Epoch 197/1000] [Accuracy  : 0.732587]
# [Epoch 198/1000] [Train_Loss: 0.560143 /Valid_Loss: 0.599610]
# [Epoch 198/1000] [Accuracy  : 0.733225]
# [Epoch 199/1000] [Train_Loss: 0.558936 /Valid_Loss: 0.598684]
# [Epoch 199/1000] [Accuracy  : 0.735850]
# [Epoch 200/1000] [Train_Loss: 0.546764 /Valid_Loss: 0.599482]
# [Epoch 200/1000] [Accuracy  : 0.733038]
# [Epoch 201/1000] [Train_Loss: 0.559776 /Valid_Loss: 0.598672]
# [Epoch 201/1000] [Accuracy  : 0.735800]
# [Epoch 202/1000] [Train_Loss: 0.557369 /Valid_Loss: 0.595709]
# [Epoch 202/1000] [Accuracy  : 0.734463]
# [Epoch 203/1000] [Train_Loss: 0.566126 /Valid_Loss: 0.595676]
# [Epoch 203/1000] [Accuracy  : 0.736350]
# [Epoch 204/1000] [Train_Loss: 0.545594 /Valid_Loss: 0.599882]
# [Epoch 204/1000] [Accuracy  : 0.732650]
# [Epoch 205/1000] [Train_Loss: 0.553999 /Valid_Loss: 0.600364]
# [Epoch 205/1000] [Accuracy  : 0.734187]
# [Epoch 206/1000] [Train_Loss: 0.553456 /Valid_Loss: 0.592656]
# [Epoch 206/1000] [Accuracy  : 0.738463]
# [Epoch 207/1000] [Train_Loss: 0.556422 /Valid_Loss: 0.597701]
# [Epoch 207/1000] [Accuracy  : 0.735788]
# [Epoch 208/1000] [Train_Loss: 0.544496 /Valid_Loss: 0.594210]
# [Epoch 208/1000] [Accuracy  : 0.738237]
# [Epoch 209/1000] [Train_Loss: 0.549425 /Valid_Loss: 0.592467]
# [Epoch 209/1000] [Accuracy  : 0.739437]
# [Epoch 210/1000] [Train_Loss: 0.554354 /Valid_Loss: 0.599812]
# [Epoch 210/1000] [Accuracy  : 0.735325]
# [Epoch 211/1000] [Train_Loss: 0.546551 /Valid_Loss: 0.594238]
# [Epoch 211/1000] [Accuracy  : 0.739175]
# [Epoch 212/1000] [Train_Loss: 0.563010 /Valid_Loss: 0.598572]
# [Epoch 212/1000] [Accuracy  : 0.734950]
# [Epoch 213/1000] [Train_Loss: 0.558372 /Valid_Loss: 0.592485]
# [Epoch 213/1000] [Accuracy  : 0.739537]
# [Epoch 214/1000] [Train_Loss: 0.547049 /Valid_Loss: 0.593877]
# [Epoch 214/1000] [Accuracy  : 0.737850]
# [Epoch 215/1000] [Train_Loss: 0.529500 /Valid_Loss: 0.593651]
# [Epoch 215/1000] [Accuracy  : 0.739175]
# [Epoch 216/1000] [Train_Loss: 0.567810 /Valid_Loss: 0.593528]
# [Epoch 216/1000] [Accuracy  : 0.738350]
# [Epoch 217/1000] [Train_Loss: 0.547973 /Valid_Loss: 0.593864]
# [Epoch 217/1000] [Accuracy  : 0.739450]
# [Epoch 218/1000] [Train_Loss: 0.562802 /Valid_Loss: 0.594699]
# [Epoch 218/1000] [Accuracy  : 0.737950]
# [Epoch 219/1000] [Train_Loss: 0.563744 /Valid_Loss: 0.594530]
# [Epoch 219/1000] [Accuracy  : 0.738550]
# [Epoch 220/1000] [Train_Loss: 0.539366 /Valid_Loss: 0.595250]
# [Epoch 220/1000] [Accuracy  : 0.737788]
# [Epoch 221/1000] [Train_Loss: 0.558444 /Valid_Loss: 0.593985]
# [Epoch 221/1000] [Accuracy  : 0.738125]
# [Epoch 222/1000] [Train_Loss: 0.560540 /Valid_Loss: 0.596856]
# [Epoch 222/1000] [Accuracy  : 0.737038]
# [Epoch 223/1000] [Train_Loss: 0.558472 /Valid_Loss: 0.591415]
# [Epoch 223/1000] [Accuracy  : 0.740912]
# [Epoch 224/1000] [Train_Loss: 0.553942 /Valid_Loss: 0.592019]
# [Epoch 224/1000] [Accuracy  : 0.740600]
# [Epoch 225/1000] [Train_Loss: 0.537279 /Valid_Loss: 0.592922]
# [Epoch 225/1000] [Accuracy  : 0.740325]
# [Epoch 226/1000] [Train_Loss: 0.543064 /Valid_Loss: 0.589219]
# [Epoch 226/1000] [Accuracy  : 0.741925]
# [Epoch 227/1000] [Train_Loss: 0.541508 /Valid_Loss: 0.590943]
# [Epoch 227/1000] [Accuracy  : 0.742500]
# [Epoch 228/1000] [Train_Loss: 0.554842 /Valid_Loss: 0.592749]
# [Epoch 228/1000] [Accuracy  : 0.741138]
# [Epoch 229/1000] [Train_Loss: 0.550080 /Valid_Loss: 0.590107]
# [Epoch 229/1000] [Accuracy  : 0.742062]
# [Epoch 230/1000] [Train_Loss: 0.546299 /Valid_Loss: 0.589747]
# [Epoch 230/1000] [Accuracy  : 0.743263]
# [Epoch 231/1000] [Train_Loss: 0.543602 /Valid_Loss: 0.593652]
# [Epoch 231/1000] [Accuracy  : 0.739075]
# [Epoch 232/1000] [Train_Loss: 0.565292 /Valid_Loss: 0.589926]
# [Epoch 232/1000] [Accuracy  : 0.741125]
# [Epoch 233/1000] [Train_Loss: 0.545193 /Valid_Loss: 0.587994]
# [Epoch 233/1000] [Accuracy  : 0.744275]
# [Epoch 234/1000] [Train_Loss: 0.539707 /Valid_Loss: 0.589005]
# [Epoch 234/1000] [Accuracy  : 0.743000]
# [Epoch 235/1000] [Train_Loss: 0.560730 /Valid_Loss: 0.590588]
# [Epoch 235/1000] [Accuracy  : 0.741925]
# [Epoch 236/1000] [Train_Loss: 0.543268 /Valid_Loss: 0.592325]
# [Epoch 236/1000] [Accuracy  : 0.740012]
# [Epoch 237/1000] [Train_Loss: 0.559813 /Valid_Loss: 0.590369]
# [Epoch 237/1000] [Accuracy  : 0.741537]
# [Epoch 238/1000] [Train_Loss: 0.517599 /Valid_Loss: 0.595564]
# [Epoch 238/1000] [Accuracy  : 0.738200]
# [Epoch 239/1000] [Train_Loss: 0.537522 /Valid_Loss: 0.590742]
# [Epoch 239/1000] [Accuracy  : 0.740975]
# [Epoch 240/1000] [Train_Loss: 0.532583 /Valid_Loss: 0.593354]
# [Epoch 240/1000] [Accuracy  : 0.740387]
# [Epoch 241/1000] [Train_Loss: 0.543669 /Valid_Loss: 0.588218]
# [Epoch 241/1000] [Accuracy  : 0.741213]
# [Epoch 242/1000] [Train_Loss: 0.568041 /Valid_Loss: 0.589785]
# [Epoch 242/1000] [Accuracy  : 0.743162]
# [Epoch 243/1000] [Train_Loss: 0.534156 /Valid_Loss: 0.591155]
# [Epoch 243/1000] [Accuracy  : 0.743888]
# [Epoch 244/1000] [Train_Loss: 0.543837 /Valid_Loss: 0.588582]
# [Epoch 244/1000] [Accuracy  : 0.743012]
# [Epoch 245/1000] [Train_Loss: 0.558377 /Valid_Loss: 0.590534]
# [Epoch 245/1000] [Accuracy  : 0.743363]
# [Epoch 246/1000] [Train_Loss: 0.542314 /Valid_Loss: 0.590360]
# [Epoch 246/1000] [Accuracy  : 0.741337]
# [Epoch 247/1000] [Train_Loss: 0.536715 /Valid_Loss: 0.591840]
# [Epoch 247/1000] [Accuracy  : 0.739550]
# [Epoch 248/1000] [Train_Loss: 0.534226 /Valid_Loss: 0.590070]
# [Epoch 248/1000] [Accuracy  : 0.742138]
# [Epoch 249/1000] [Train_Loss: 0.555372 /Valid_Loss: 0.588654]
# [Epoch 249/1000] [Accuracy  : 0.742025]
# [Epoch 250/1000] [Train_Loss: 0.537755 /Valid_Loss: 0.590578]
# [Epoch 250/1000] [Accuracy  : 0.743025]
# [Epoch 251/1000] [Train_Loss: 0.541355 /Valid_Loss: 0.587964]
# [Epoch 251/1000] [Accuracy  : 0.744400]
# [Epoch 252/1000] [Train_Loss: 0.525067 /Valid_Loss: 0.589618]
# [Epoch 252/1000] [Accuracy  : 0.742425]
# [Epoch 253/1000] [Train_Loss: 0.550997 /Valid_Loss: 0.589774]
# [Epoch 253/1000] [Accuracy  : 0.744475]
# [Epoch 254/1000] [Train_Loss: 0.543778 /Valid_Loss: 0.591238]
# [Epoch 254/1000] [Accuracy  : 0.741875]
# [Epoch 255/1000] [Train_Loss: 0.542808 /Valid_Loss: 0.588380]
# [Epoch 255/1000] [Accuracy  : 0.743275]
# [Epoch 256/1000] [Train_Loss: 0.537331 /Valid_Loss: 0.587801]
# [Epoch 256/1000] [Accuracy  : 0.742850]
# [Epoch 257/1000] [Train_Loss: 0.550592 /Valid_Loss: 0.587973]
# [Epoch 257/1000] [Accuracy  : 0.744325]
# [Epoch 258/1000] [Train_Loss: 0.532390 /Valid_Loss: 0.588071]
# [Epoch 258/1000] [Accuracy  : 0.744463]
# [Epoch 259/1000] [Train_Loss: 0.542402 /Valid_Loss: 0.593710]
# [Epoch 259/1000] [Accuracy  : 0.740463]
# [Epoch 260/1000] [Train_Loss: 0.530119 /Valid_Loss: 0.592446]
# [Epoch 260/1000] [Accuracy  : 0.741487]
# [Epoch 261/1000] [Train_Loss: 0.551954 /Valid_Loss: 0.586987]
# [Epoch 261/1000] [Accuracy  : 0.743838]
# [Epoch 262/1000] [Train_Loss: 0.530012 /Valid_Loss: 0.590540]
# [Epoch 262/1000] [Accuracy  : 0.742525]
# [Epoch 263/1000] [Train_Loss: 0.547783 /Valid_Loss: 0.589854]
# [Epoch 263/1000] [Accuracy  : 0.742962]
# [Epoch 264/1000] [Train_Loss: 0.554298 /Valid_Loss: 0.588421]
# [Epoch 264/1000] [Accuracy  : 0.743375]
# [Epoch 265/1000] [Train_Loss: 0.549555 /Valid_Loss: 0.590805]
# [Epoch 265/1000] [Accuracy  : 0.742738]
# [Epoch 266/1000] [Train_Loss: 0.539640 /Valid_Loss: 0.588076]
# [Epoch 266/1000] [Accuracy  : 0.740875]
# [Epoch 267/1000] [Train_Loss: 0.539073 /Valid_Loss: 0.587539]
# [Epoch 267/1000] [Accuracy  : 0.743750]
# [Epoch 268/1000] [Train_Loss: 0.548287 /Valid_Loss: 0.590322]
# [Epoch 268/1000] [Accuracy  : 0.743325]
# [Epoch 269/1000] [Train_Loss: 0.545925 /Valid_Loss: 0.589344]
# [Epoch 269/1000] [Accuracy  : 0.744587]
# [Epoch 270/1000] [Train_Loss: 0.531340 /Valid_Loss: 0.589457]
# [Epoch 270/1000] [Accuracy  : 0.743900]
# [Epoch 271/1000] [Train_Loss: 0.531874 /Valid_Loss: 0.592313]
# [Epoch 271/1000] [Accuracy  : 0.740738]
# [Epoch 272/1000] [Train_Loss: 0.526600 /Valid_Loss: 0.588805]
# [Epoch 272/1000] [Accuracy  : 0.744587]
# [Epoch 273/1000] [Train_Loss: 0.543743 /Valid_Loss: 0.593127]
# [Epoch 273/1000] [Accuracy  : 0.741363]
# [Epoch 274/1000] [Train_Loss: 0.566457 /Valid_Loss: 0.591590]
# [Epoch 274/1000] [Accuracy  : 0.742537]
# [Epoch 275/1000] [Train_Loss: 0.524859 /Valid_Loss: 0.589581]
# [Epoch 275/1000] [Accuracy  : 0.742775]
# [Epoch 276/1000] [Train_Loss: 0.532849 /Valid_Loss: 0.588203]
# [Epoch 276/1000] [Accuracy  : 0.743537]
# [Epoch 277/1000] [Train_Loss: 0.545975 /Valid_Loss: 0.589189]
# [Epoch 277/1000] [Accuracy  : 0.745125]
# [Epoch 278/1000] [Train_Loss: 0.533901 /Valid_Loss: 0.587153]
# [Epoch 278/1000] [Accuracy  : 0.746525]
# [Epoch 279/1000] [Train_Loss: 0.525356 /Valid_Loss: 0.587724]
# [Epoch 279/1000] [Accuracy  : 0.745988]
# [Epoch 280/1000] [Train_Loss: 0.562096 /Valid_Loss: 0.588634]
# [Epoch 280/1000] [Accuracy  : 0.743750]
# [Epoch 281/1000] [Train_Loss: 0.530446 /Valid_Loss: 0.587621]
# [Epoch 281/1000] [Accuracy  : 0.743962]
# [Epoch 282/1000] [Train_Loss: 0.541564 /Valid_Loss: 0.589346]
# [Epoch 282/1000] [Accuracy  : 0.742175]
# [Epoch 283/1000] [Train_Loss: 0.539652 /Valid_Loss: 0.586875]
# [Epoch 283/1000] [Accuracy  : 0.744637]
# [Epoch 284/1000] [Train_Loss: 0.540977 /Valid_Loss: 0.586846]
# [Epoch 284/1000] [Accuracy  : 0.745775]
# [Epoch 285/1000] [Train_Loss: 0.520474 /Valid_Loss: 0.586563]
# [Epoch 285/1000] [Accuracy  : 0.744800]
# [Epoch 286/1000] [Train_Loss: 0.529463 /Valid_Loss: 0.588943]
# [Epoch 286/1000] [Accuracy  : 0.743900]
# [Epoch 287/1000] [Train_Loss: 0.531313 /Valid_Loss: 0.589166]
# [Epoch 287/1000] [Accuracy  : 0.746050]
# [Epoch 288/1000] [Train_Loss: 0.554341 /Valid_Loss: 0.588843]
# [Epoch 288/1000] [Accuracy  : 0.744463]
# [Epoch 289/1000] [Train_Loss: 0.528186 /Valid_Loss: 0.590456]
# [Epoch 289/1000] [Accuracy  : 0.742762]
# [Epoch 290/1000] [Train_Loss: 0.527294 /Valid_Loss: 0.590658]
# [Epoch 290/1000] [Accuracy  : 0.743138]
# [Epoch 291/1000] [Train_Loss: 0.541797 /Valid_Loss: 0.588152]
# [Epoch 291/1000] [Accuracy  : 0.745225]
# [Epoch 292/1000] [Train_Loss: 0.554215 /Valid_Loss: 0.587767]
# [Epoch 292/1000] [Accuracy  : 0.745237]
# [Epoch 293/1000] [Train_Loss: 0.531532 /Valid_Loss: 0.589696]
# [Epoch 293/1000] [Accuracy  : 0.744812]
# [Epoch 294/1000] [Train_Loss: 0.532692 /Valid_Loss: 0.587184]
# [Epoch 294/1000] [Accuracy  : 0.745125]
# [Epoch 295/1000] [Train_Loss: 0.514265 /Valid_Loss: 0.590719]
# [Epoch 295/1000] [Accuracy  : 0.743437]
# [Epoch 296/1000] [Train_Loss: 0.537155 /Valid_Loss: 0.588073]
# [Epoch 296/1000] [Accuracy  : 0.744800]
# [Epoch 297/1000] [Train_Loss: 0.531212 /Valid_Loss: 0.590764]
# [Epoch 297/1000] [Accuracy  : 0.741525]
# [Epoch 298/1000] [Train_Loss: 0.550947 /Valid_Loss: 0.588393]
# [Epoch 298/1000] [Accuracy  : 0.743613]
# [Epoch 299/1000] [Train_Loss: 0.513347 /Valid_Loss: 0.586065]
# [Epoch 299/1000] [Accuracy  : 0.745287]
# [Epoch 300/1000] [Train_Loss: 0.546368 /Valid_Loss: 0.591612]
# [Epoch 300/1000] [Accuracy  : 0.743287]
# [Epoch 301/1000] [Train_Loss: 0.531446 /Valid_Loss: 0.585624]
# [Epoch 301/1000] [Accuracy  : 0.746300]
# [Epoch 302/1000] [Train_Loss: 0.538896 /Valid_Loss: 0.584256]
# [Epoch 302/1000] [Accuracy  : 0.746788]
# [Epoch 303/1000] [Train_Loss: 0.527667 /Valid_Loss: 0.586544]
# [Epoch 303/1000] [Accuracy  : 0.745450]
# [Epoch 304/1000] [Train_Loss: 0.519023 /Valid_Loss: 0.587158]
# [Epoch 304/1000] [Accuracy  : 0.746250]
# [Epoch 305/1000] [Train_Loss: 0.551556 /Valid_Loss: 0.584579]
# [Epoch 305/1000] [Accuracy  : 0.745862]
# [Epoch 306/1000] [Train_Loss: 0.531150 /Valid_Loss: 0.585738]
# [Epoch 306/1000] [Accuracy  : 0.745900]
# [Epoch 307/1000] [Train_Loss: 0.548222 /Valid_Loss: 0.589713]
# [Epoch 307/1000] [Accuracy  : 0.743950]
# [Epoch 308/1000] [Train_Loss: 0.530272 /Valid_Loss: 0.591681]
# [Epoch 308/1000] [Accuracy  : 0.742188]
# [Epoch 309/1000] [Train_Loss: 0.524339 /Valid_Loss: 0.589208]
# [Epoch 309/1000] [Accuracy  : 0.744225]
# [Epoch 310/1000] [Train_Loss: 0.538420 /Valid_Loss: 0.591209]
# [Epoch 310/1000] [Accuracy  : 0.743125]
# [Epoch 311/1000] [Train_Loss: 0.527997 /Valid_Loss: 0.588088]
# [Epoch 311/1000] [Accuracy  : 0.745575]
# [Epoch 312/1000] [Train_Loss: 0.531049 /Valid_Loss: 0.586517]
# [Epoch 312/1000] [Accuracy  : 0.745088]
# [Epoch 313/1000] [Train_Loss: 0.521997 /Valid_Loss: 0.584362]
# [Epoch 313/1000] [Accuracy  : 0.747912]
# [Epoch 314/1000] [Train_Loss: 0.541786 /Valid_Loss: 0.589363]
# [Epoch 314/1000] [Accuracy  : 0.744487]
# [Epoch 315/1000] [Train_Loss: 0.530634 /Valid_Loss: 0.590607]
# [Epoch 315/1000] [Accuracy  : 0.743100]
# [Epoch 316/1000] [Train_Loss: 0.541332 /Valid_Loss: 0.591735]
# [Epoch 316/1000] [Accuracy  : 0.743012]
# [Epoch 317/1000] [Train_Loss: 0.543300 /Valid_Loss: 0.588889]
# [Epoch 317/1000] [Accuracy  : 0.744175]
# [Epoch 318/1000] [Train_Loss: 0.515731 /Valid_Loss: 0.589219]
# [Epoch 318/1000] [Accuracy  : 0.744850]
# [Epoch 319/1000] [Train_Loss: 0.526567 /Valid_Loss: 0.589572]
# [Epoch 319/1000] [Accuracy  : 0.744725]
# [Epoch 320/1000] [Train_Loss: 0.533648 /Valid_Loss: 0.587661]
# [Epoch 320/1000] [Accuracy  : 0.745762]
# [Epoch 321/1000] [Train_Loss: 0.540903 /Valid_Loss: 0.591490]
# [Epoch 321/1000] [Accuracy  : 0.741825]
# [Epoch 322/1000] [Train_Loss: 0.519024 /Valid_Loss: 0.585004]
# [Epoch 322/1000] [Accuracy  : 0.746387]
# [Epoch 323/1000] [Train_Loss: 0.528992 /Valid_Loss: 0.586430]
# [Epoch 323/1000] [Accuracy  : 0.745875]
# [Epoch 324/1000] [Train_Loss: 0.530503 /Valid_Loss: 0.585150]
# [Epoch 324/1000] [Accuracy  : 0.746138]
# [Epoch 325/1000] [Train_Loss: 0.527184 /Valid_Loss: 0.587830]
# [Epoch 325/1000] [Accuracy  : 0.744363]
# [Epoch 326/1000] [Train_Loss: 0.539293 /Valid_Loss: 0.586470]
# [Epoch 326/1000] [Accuracy  : 0.744950]
# [Epoch 327/1000] [Train_Loss: 0.536469 /Valid_Loss: 0.587794]
# [Epoch 327/1000] [Accuracy  : 0.745687]
# [Epoch 328/1000] [Train_Loss: 0.515014 /Valid_Loss: 0.587008]
# [Epoch 328/1000] [Accuracy  : 0.746650]
# [Epoch 329/1000] [Train_Loss: 0.527478 /Valid_Loss: 0.586757]
# [Epoch 329/1000] [Accuracy  : 0.747138]
# [Epoch 330/1000] [Train_Loss: 0.535661 /Valid_Loss: 0.589561]
# [Epoch 330/1000] [Accuracy  : 0.743775]
# [Epoch 331/1000] [Train_Loss: 0.530224 /Valid_Loss: 0.592222]
# [Epoch 331/1000] [Accuracy  : 0.742100]
# [Epoch 332/1000] [Train_Loss: 0.540787 /Valid_Loss: 0.587045]
# [Epoch 332/1000] [Accuracy  : 0.744825]
# [Epoch 333/1000] [Train_Loss: 0.530963 /Valid_Loss: 0.582819]
# [Epoch 333/1000] [Accuracy  : 0.747212]
# [Epoch 334/1000] [Train_Loss: 0.537135 /Valid_Loss: 0.586067]
# [Epoch 334/1000] [Accuracy  : 0.745513]
# [Epoch 335/1000] [Train_Loss: 0.537989 /Valid_Loss: 0.590343]
# [Epoch 335/1000] [Accuracy  : 0.743725]
# [Epoch 336/1000] [Train_Loss: 0.523878 /Valid_Loss: 0.587153]
# [Epoch 336/1000] [Accuracy  : 0.744600]
# [Epoch 337/1000] [Train_Loss: 0.531135 /Valid_Loss: 0.588168]
# [Epoch 337/1000] [Accuracy  : 0.744962]
# [Epoch 338/1000] [Train_Loss: 0.532957 /Valid_Loss: 0.585990]
# [Epoch 338/1000] [Accuracy  : 0.745675]
# [Epoch 339/1000] [Train_Loss: 0.542657 /Valid_Loss: 0.588232]
# [Epoch 339/1000] [Accuracy  : 0.744200]
# [Epoch 340/1000] [Train_Loss: 0.542494 /Valid_Loss: 0.584556]
# [Epoch 340/1000] [Accuracy  : 0.746900]
# [Epoch 341/1000] [Train_Loss: 0.518129 /Valid_Loss: 0.587677]
# [Epoch 341/1000] [Accuracy  : 0.745513]
# [Epoch 342/1000] [Train_Loss: 0.548720 /Valid_Loss: 0.587863]
# [Epoch 342/1000] [Accuracy  : 0.744938]
# [Epoch 343/1000] [Train_Loss: 0.517595 /Valid_Loss: 0.588788]
# [Epoch 343/1000] [Accuracy  : 0.743413]
# [Epoch 344/1000] [Train_Loss: 0.521904 /Valid_Loss: 0.587008]
# [Epoch 344/1000] [Accuracy  : 0.744563]
# [Epoch 345/1000] [Train_Loss: 0.533335 /Valid_Loss: 0.587718]
# [Epoch 345/1000] [Accuracy  : 0.743150]
# [Epoch 346/1000] [Train_Loss: 0.536147 /Valid_Loss: 0.588503]
# [Epoch 346/1000] [Accuracy  : 0.745375]
# [Epoch 347/1000] [Train_Loss: 0.537808 /Valid_Loss: 0.585734]
# [Epoch 347/1000] [Accuracy  : 0.747313]
# [Epoch 348/1000] [Train_Loss: 0.522102 /Valid_Loss: 0.586866]
# [Epoch 348/1000] [Accuracy  : 0.745825]
# [Epoch 349/1000] [Train_Loss: 0.533508 /Valid_Loss: 0.586448]
# [Epoch 349/1000] [Accuracy  : 0.745650]
# [Epoch 350/1000] [Train_Loss: 0.521004 /Valid_Loss: 0.587356]
# [Epoch 350/1000] [Accuracy  : 0.745613]
# [Epoch 351/1000] [Train_Loss: 0.530670 /Valid_Loss: 0.584564]
# [Epoch 351/1000] [Accuracy  : 0.746875]
# [Epoch 352/1000] [Train_Loss: 0.531475 /Valid_Loss: 0.583721]
# [Epoch 352/1000] [Accuracy  : 0.746450]
# [Epoch 353/1000] [Train_Loss: 0.529725 /Valid_Loss: 0.587318]
# [Epoch 353/1000] [Accuracy  : 0.745988]
# [Epoch 354/1000] [Train_Loss: 0.548048 /Valid_Loss: 0.590686]
# [Epoch 354/1000] [Accuracy  : 0.743150]
# [Epoch 355/1000] [Train_Loss: 0.541352 /Valid_Loss: 0.586463]
# [Epoch 355/1000] [Accuracy  : 0.745475]
# [Epoch 356/1000] [Train_Loss: 0.519304 /Valid_Loss: 0.585354]
# [Epoch 356/1000] [Accuracy  : 0.746062]
# [Epoch 357/1000] [Train_Loss: 0.528422 /Valid_Loss: 0.588077]
# [Epoch 357/1000] [Accuracy  : 0.745625]
# [Epoch 358/1000] [Train_Loss: 0.548098 /Valid_Loss: 0.586188]
# [Epoch 358/1000] [Accuracy  : 0.746138]
# [Epoch 359/1000] [Train_Loss: 0.527193 /Valid_Loss: 0.585060]
# [Epoch 359/1000] [Accuracy  : 0.745475]
# [Epoch 360/1000] [Train_Loss: 0.523353 /Valid_Loss: 0.585199]
# [Epoch 360/1000] [Accuracy  : 0.747275]
# [Epoch 361/1000] [Train_Loss: 0.531157 /Valid_Loss: 0.586525]
# [Epoch 361/1000] [Accuracy  : 0.746025]
# [Epoch 362/1000] [Train_Loss: 0.531247 /Valid_Loss: 0.585814]
# [Epoch 362/1000] [Accuracy  : 0.745275]
# [Epoch 363/1000] [Train_Loss: 0.530101 /Valid_Loss: 0.586781]
# [Epoch 363/1000] [Accuracy  : 0.745162]
# [Epoch 364/1000] [Train_Loss: 0.535134 /Valid_Loss: 0.587610]
# [Epoch 364/1000] [Accuracy  : 0.745287]
# This is time to do early stopping
# 모델 저장: /content/gdrive/My Drive/Colab Notebooks/ai_mfg/rotor/rnn_model.pt

# %% [markdown]
# #### (1) 모델 평가

# %%
PATH = dir+'rnn_'
test_model(RNN_model, PATH)
# Out:
# 0.7683375

# %% [markdown]
# #### (2) 혼동 행렬 (Confusion matrix)

# %%
draw_confusion_matrix(RNN_model, x_test, y_test, PATH)

# %% [markdown]
# #### (3) 손실(Loss) 그래프

# %%
plot_loss_graph(RNN_loss_values, RNN_loss_values_v)

# %% [markdown]
# <a href="https://colab.research.google.com/github/jjyjung/ai_mfg/blob/main/Day1_pima_indians_diabetes(%ED%95%99%EC%83%9D%EC%9A%A9)_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **1. 데이터 업로드**

# %%
### Colab에서 Google Drive에 저장된 파일에 접근할 때 필요한 코드
from google.colab import drive
drive.mount('/content/gdrive')   # google drive를 google colab에 연결. 처음 실행 시, 인증 필요
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_1053/1677450229.py in <cell line: 0>()
#       1 ### Colab에서 Google Drive에 저장된 파일에 접근할 때 필요한 코드
#       2 from google.colab import drive
# ----> 3 drive.mount('/content/gdrive')   # google drive를 google colab에 연결. 처음 실행 시, 인증 필요
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

dir = "/content/gdrive/My Drive/Colab Notebooks/ai_ngv/"  ### [중요!!] Colab의 경우, 파일을 저장한 위치를 기록하시오.
path = dir + 'data/pima-indians-diabetes.data.csv'

data = pd.read_csv(path)
data.head()

# %% [markdown]
# ## **2. 기술 통계량**

# %%
print(data.shape)
print(data.dtypes)
print(data.describe())

# %%
from pandas import set_option
set_option('display.precision', 2)

print(data.shape)
print(data.dtypes)
print(data.describe())

# %% [markdown]
# ## **3. 그래프 가시화 (단변량)**

# %%
# 데이터 히스토그램
data.hist()
plt.show()

# 커널 밀도 추정 그래프
data.plot(kind='density')
plt.show()

# 박스 플롯
data.plot(kind='box')
plt.gca().set_ylabel("Frequency")
plt.show()

# %%
data.hist()
plt.tight_layout()      # 그래프 요소가 겹치지 않도록 레이아웃 조정
plt.show()

data.plot(kind='density', subplots=True, layout=(3,3), sharex=False, sharey=False)
plt.tight_layout()      # 그래프 요소가 겹치지 않도록 레이아웃 조정
plt.show()

data.plot(kind='box', subplots=True, layout=(3,3), sharex=False, sharey=False)
plt.tight_layout()      # 그래프 요소가 겹치지 않도록 레이아웃 조정
plt.show()

# %% [markdown]
# ### [실습] Pima 인디언 당뇨병 데이터로 아래와 같이 그래프를 그려보시오.
# ![image.png](data:image/png;base64,...)

# %%
# 데이터 히스토그램



# 커널 밀도 추정 그래프



# 박스 플롯

# %% [markdown]
# ## **4. 그래프 가시화 (다변량)**

# %%
# Class Distribution
class_counts = data.groupby('class').size()
print(class_counts)

# Pairwise Pearson correlations
from pandas import set_option
set_option('display.width', 100)
set_option('display.precision', 3)
correlations = data.corr(method='pearson')
print(correlations)

# %%
fig, ax = plt.subplots(figsize=(7, 4))
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)

ticks = np.arange(len(data.columns))   # ticks = [0, 1, … , 8]
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(data.columns)
ax.set_yticklabels(data.columns)
plt.show()

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(data, figsize=(12, 12))
plt.subplots_adjust(hspace=0.2, wspace=0.2)  # 세로, 가로 간격 조정
plt.show()

# %%
# 데이터 읽기, 잘못된 행 무시
data = pd.read_csv(path, on_bad_lines='skip')

# 숫자형 열만 선택
numeric_data = data.select_dtypes(include=[int, float])

# scatter_matrix 그리기
scatter_matrix(numeric_data, figsize=(12, 12))
plt.subplots_adjust(hspace=0.2, wspace=0.2)  # 세로, 가로 간격 조정
plt.show()

# %% [markdown]
# ### [토의] 당뇨병 예측에 도움이 되는 컬럼(Feature)는 어떤 것이라고 생각하는가?
